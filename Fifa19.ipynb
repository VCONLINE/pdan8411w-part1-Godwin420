# %% [markdown]
# ## Kaggle dataset used
# Kaggle. (7 April 2024). FIFA 19 complete player dataset.
#
# ## Why this dataset is suitable for linear regression
#
# The FIFA 19 dataset from Kaggle presents suitability for linear regression analysis for several compelling reasons:
#
# Quantitative Variables: Abundant quantitative variables populate the dataset, encompassing player ratings, potential, and wages. Such variables can serve interchangeably as either dependent or independent variables within a linear regression framework (Kaggle, 7 April 2024).
#
# Predictive Modeling: A predominant objective across various projects utilizing this dataset involves forecasting a player’s overall rating based on their inherent characteristics. This objective aligns seamlessly with the application of linear regression, reflecting a typical use case for this statistical technique (Kaggle, 7 April 2024).
#
# Good Model Fit: Reports from prior projects employing linear regression with this dataset highlight commendable model fit, as evidenced by performance metrics like R-squared. This observation underscores the effectiveness of linear regression in elucidating relationships within the dataset (GitHub - julielyq, 7 April 2024).
#
# Versatility: The dataset’s versatility extends to accommodating diverse regression analyses, encompassing both simple and multiple linear regression models. This flexibility augments the dataset's utility in exploring various facets of the data through regression analysis (GitHub - rithwikrajendran, 7 April 2024).
#
# The key assumptions of linear regression and why they are crucial for ensuring the robustness and reliability of the analysis:
#
# Linearity: This assumption posits that there exists a linear relationship between the independent variables and the dependent variable. In other words, the change in the dependent variable is directly proportional to changes in the independent variables. Linear regression models assume that the relationship can be adequately captured by a straight line. Deviations from linearity can lead to biased estimates and inaccurate predictions. (Kaggle, 7 April 2024).
#
# Independence: Independence assumes that the observations or data points used in the regression analysis are not influenced by each other. Each observation should be independent of all others. Violations of independence, such as autocorrelation in time-series data or clustering effects in clustered data, can lead to biased standard errors and inflated significance levels. (Kaggle, 7 April 2024).
#
# Homoscedasticity: Homoscedasticity refers to the assumption that the variance of the residuals (the differences between observed and predicted values) is constant across all levels of the independent variables. In simpler terms, it implies that the spread of the residuals should be uniform across the range of predicted values. Heteroscedasticity, where the spread of residuals varies across different levels of the independent variable, can result in inefficient parameter estimates and inaccurate confidence intervals. (Kaggle, 7 April 2024).
#
# Normality of Residuals: This assumption states that the residuals of the regression model should be normally distributed. Normality ensures that the statistical tests used for inference, such as hypothesis testing and confidence intervals, are valid. Departures from normality can affect the accuracy of parameter estimates and lead to incorrect conclusions about the significance of predictors. (Kaggle, 7 April 2024).
#
# Ensuring that these assumptions hold true is essential for the validity and reliability of the linear regression analysis. Failure to meet these assumptions can result in biased estimates, unreliable predictions, and erroneous conclusions. (Kaggle, 7 April 2024).
#
# ## References
#
# (1) Kaggle. (7 April 2024). FIFA in depth analysis with Linear Regression.
#
# (2) GitHub - julielyq. (7 April 2024). Kaggle-FIFA-19-Complete-Player-Dataset: regression.
#
# (3) GitHub - rithwikrajendran. (7 April 2024). fifa-19-linear-regression.

# %% [markdown]
# ## What is linear regression
#
# Linear regression is a statistical model used to estimate the relationship between a dependent variable and one or more independent variables. Wikipedia. (7 April 2024). It is a technique used to model the relationships between observed variables. Brilliant Math & Science Wiki. (7 April 2024). The simplest form of linear regression involves two variables: a dependent variable (y) and an independent variable (x). Britannica. (2024).
#
# The main idea behind simple linear regression is to “fit” the observations of two variables into a linear relationship between them. Brilliant Math & Science Wiki. (7 April 2024). This is achieved by determining a line that best represents the general trend of a data set. Britannica. (2024). Regression models describe the relationship between variables by fitting a line to the observed data. Scribbr. (2023). Linear regression models use a straight line, while logistic and nonlinear regression models use a curved line. Scribbr. (2023)
#
# For example, if you are a social researcher interested in the relationship between income and happiness, you might survey 500 people whose incomes range from 15k to 75k and ask them to rank their happiness on a scale from 1 to 10. Your independent variable (income) and dependent variable (happiness) are both quantitative, so you can do a regression analysis to see if there is a linear relationship between them. Scribbr. (2023).
#
# Linear regression makes certain assumptions about the data: Scribbr. (2023).
#
# Homogeneity of variance (homoscedasticity): the size of the error in our prediction doesn’t change significantly across the values of the independent variable.
# Independence of observations: the observations in the dataset were collected using statistically valid sampling methods, and there are no hidden relationships among observations.
#
# Normality: The data follows a normal distribution.
# The relationship between the independent and dependent variable is linear: the line of best fit through the data points is a straight line (rather than a curve or some sort of grouping factor).
# If your data do not meet the assumptions of homoscedasticity or normality, you may be able to use a nonparametric test instead, such as the Spearman rank test.Scribbr. (2023)
#
#
#
# The equation for a simple linear regression is typically written as:
# $y=a+bx$
# where:
#
# $y$ is the dependent variable (the variable we are trying to predict or estimate)
# $x$ is the independent variable (the variable we are using to make the prediction)
# $a$ is the y-intercept (the value of y when x=0)
# $b$ is the slope of the regression line (the change in y for a one-unit change in x). BYJU’S. (7 April 2024).
#
# In the context of multiple linear regression, where we have more than one independent variable, the equation becomes:
# $y=a+b1​x1​+b2​x2​+...+bn​xn​$
# where:
#
# $x1​,x2​,...,xn$​ are the independent variables
# $b1​,b2​,...,bn$​ are the coefficients of the independent variables (the change in y for a one-unit change in the respective independent variable)
# a is the y-intercept (the value of y when all x=0)
#
# The coefficients $b1​,b2​,...,bn​$ and the y-intercept $a$ are typically estimated using a method called least squares. Statistics By Jim. (7 April 2024). This method minimizes the sum of the squared differences between the observed dependent variable in the dataset and those predicted by the linear function. Statistics By Jim. (7 April 2024).
#
# ## References:
#
# (1) Britannica. (2024). Linear regression | Definition, Formula, & Facts | Britannica.
#
# (2) Brilliant Math & Science Wiki. (7 April 2024). Linear Regression | Brilliant Math & Science Wiki.
#
# (3) Giba, L. (7 April 2024). Linear Regression Explained, Step by Step - Machine Learning Compass.
#
# (4) Scribbr. (2023). Simple Linear Regression | An Easy Introduction & Examples - Scribbr.
#
# (5) Wikipedia. (7 April 2024). Linear regression - Wikipedia.
# Statistics By Jim. (7 April 2024). Linear Regression Equation Explained.
#
# (6) BYJU’S. (7 April 2024). Linear Regression-Equation, Formula and Properties.
#
# (7) Statology. (7 April 2024). Introduction to Simple Linear Regression.

# %% [markdown]
# ## Predicting a player's overall rating in FIFA 19 using the Kaggle dataset involves several steps:
#
# # 1. Analysis Objective:
# The primary question that this analysis aims to answer is: "Can we predict a player's overall rating based on their characteristics in the FIFA 19 dataset?"
#
# # 2. Feature Extraction:
# The dataset contains numerous features such as player age, nationality, club, and various skill ratings. We might want to extract features that are likely to have an impact on a player's overall rating. These could include 'Age', 'Potential', 'Special', 'International Reputation', 'Skill Moves', 'Work Rate', 'Body Type', 'Position', 'Height', 'Weight', and various skill ratings.
#
# # 3. Data Fitting and Model Selection:
# We can use a linear regression model to fit our data. The dependent variable would be 'Overall' (the overall rating of a player), and the independent variables would be the features we extracted. We would use a training dataset to train our model, and a test dataset to evaluate its performance.
#
# # 4. Overfitting and Underfitting:
# To avoid overfitting, we can use techniques like cross-validation, where our model is tested on a subset of our data to check its ability to generalize to unseen data. Regularization methods like Ridge or Lasso can also be used to prevent overfitting by adding a penalty term to the loss function that the model minimizes. To combat underfitting, we might need to increase the complexity of our model, such as adding more features or using a non-linear model.
#
# # 5. Libraries:
# In Python, we would likely use pandas for data manipulation, NumPy for numerical computations, matplotlib and seaborn for data visualization, and scikit-learn for building the linear regression model.
#
# # 6. Verifying Results:
# We can verify our results using various statistical measures like R-squared, Adjusted R-squared, or Root Mean Squared Error (RMSE) for regression models. These measures can tell us how well our model fits the data.
#
# # 7. Predictions:
# Once our model is trained, we can use it to predict the overall rating of players based on their characteristics.
#
# # 8. Data Visualization:
# Data visualization can be done using libraries like matplotlib and seaborn. We can create scatter plots, histograms, bar plots, and heatmaps to understand the distribution of variables and the relationships between them.
#
# ## References
#
# (1) EDA, prediction of Fifa 19 players' overall | Kaggle. https://www.kaggle.com/code/azerumudov/eda-prediction-of-fifa-19-players-overall.
#
# (2) EDA, prediction of Fifa 19 players' overall | Kaggle. https://www.kaggle.com/code/azerumudov/eda-prediction-of-fifa-19-players-overall.
#
# (3) FIFA19 ⚽ Player & Team Analysis and Value Predict | Kaggle. https://www.kaggle.com/code/lykin22/fifa19-player-team-analysis-and-value-predict.
#
# (4) FIFA 19 dataset - player's market value and game position prediction. https://github.com/timzatko/fifa-19-dataset-machine-learning.

# %%
#Import modules needed for analysis
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
# Load the dataset

df = pd.read_csv('fifa.csv', encoding='ISO-8859-1')
df.head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
# 3  https://cdn.sofifa.org/flags/45.png     91.0         93
# 4   https://cdn.sofifa.org/flags/7.png     91.0         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        226.5M
# 1      7.0        11.0       15.0           14.0       11.0        127.1M
# 2      9.0         9.0       15.0           15.0       11.0        228.1M
# 3     90.0        85.0       87.0           88.0       94.0        138.6M
# 4     15.0        13.0        5.0           10.0       13.0        196.4M
#
# [5 rows x 89 columns]

# %%
#Top 10 natioanilities, number of players by country
top_countries = df['Nationality'].value_counts().head(10)

plt.figure(figsize=(10,6))
top_countries.plot(kind='bar')
plt.xlabel('Nationality')
plt.ylabel('Number of Players')
plt.title('Top 10 Nationalities in Number of Players')
plt.show()

# %%
#Graph showing position by overall rating
plt.figure(figsize=(10,6))
sns.boxplot(x='Position', y='Overall', data=df)
plt.xlabel('Position')
plt.ylabel('Overall Rating')
plt.title('Distribution of Overall Ratings by Position')
plt.xticks(rotation=90)  # Rotate x-axis labels for readability
plt.show()

# %%
df.shape
# Out:
# (18207, 89)

# %%
#removing spaces from columns
df.columns = [c.replace(' ', '') for c in df.columns]
df.columns
# Out:
# Index(['Unnamed:0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'ClubLogo', 'Value', 'Wage', 'Special',
#        'PreferredFoot', 'InternationalReputation', 'WeakFoot', 'SkillMoves',
#        'WorkRate', 'BodyType', 'RealFace', 'Position', 'JerseyNumber',
#        'Joined', 'LoanedFrom', 'ContractValidUntil', 'Height', 'Weight', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
#        'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
#        'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle',
#        'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes',
#        'ReleaseClause'],
#       dtype='object')

# %%
#Creating Dateframe with playars BELOW 85 overall
df = df.query("Overall<=90")
df.head()
# Out:
#     Unnamed:0      ID            Name   Age  \
# 9           9  200389        J. Oblak  25.0
# 10         10  188545  R. Lewandowski  29.0
# 11         11  182521        T. Kroos   NaN
# 12         12  182493        D. Godín  32.0
# 13         13  168542     David Silva  32.0
#
#                                              Photo Nationality  \
# 9   https://cdn.sofifa.org/players/4/19/200389.png    Slovenia
# 10  https://cdn.sofifa.org/players/4/19/188545.png      Poland
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 12  https://cdn.sofifa.org/players/4/19/182493.png     Uruguay
# 13  https://cdn.sofifa.org/players/4/19/168542.png       Spain
#
#                                    Flag  Overall  Potential  \
# 9   https://cdn.sofifa.org/flags/44.png     90.0         93
# 10  https://cdn.sofifa.org/flags/37.png     90.0         90
# 11  https://cdn.sofifa.org/flags/21.png     90.0         90
# 12  https://cdn.sofifa.org/flags/60.png     90.0         90
# 13  https://cdn.sofifa.org/flags/45.png     90.0         90
#
#                  Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 9     Atlético Madrid  ...      70.0    27.0           12.0           18.0
# 10  FC Bayern München  ...      86.0    34.0           42.0           19.0
# 11        Real Madrid  ...      85.0    72.0           79.0           69.0
# 12    Atlético Madrid  ...      82.0    90.0           89.0           89.0
# 13    Manchester City  ...      93.0    59.0           53.0           29.0
#
#    GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes ReleaseClause
# 9      86.0        92.0       78.0           88.0       89.0       144.5M
# 10     15.0         6.0       12.0            8.0       10.0       127.1M
# 11     10.0        11.0       13.0            7.0       10.0       156.8M
# 12      6.0         8.0       15.0            5.0       15.0        90.2M
# 13      6.0        15.0        7.0            6.0       12.0         111M
#
# [5 rows x 89 columns]

# %%
#remove data not needed or wanted
df.drop(["Unnamed:0","GKDiving", "GKHandling", "GKKicking", "GKPositioning", "GKReflexes",
       "ReleaseClause", "ID", "Name",  "Photo", "Nationality", "Flag",
        "Club", "ClubLogo", "Special",
       "PreferredFoot", "InternationalReputation",
       "WorkRate", "BodyType", "RealFace", "Position", "JerseyNumber",
       "Joined", "LoanedFrom", "ContractValidUntil", "Height", "Weight", "LS",
       "ST", "RS", "LW", "LF", "CF", "RF", "RW", "LAM", "CAM", "RAM", "LM",
       "LCM", "CM", "RCM", "RM", "LWB", "LDM", "CDM", "RDM", "RWB", "LB",
       "LCB", "CB", "RCB", "RB",],axis=1,inplace=True)
df.head()
# Out:
#      Age  Overall  Potential   Value   Wage  WeakFoot  SkillMoves  Crossing  \
# 9   25.0     90.0         93    68M   94K       3.0         1.0      13.0
# 10  29.0     90.0         90    77M  205K       4.0         4.0      62.0
# 11   NaN     90.0         90  76.5M  355K       5.0         3.0      88.0
# 12  32.0     90.0         90    44M  125K       3.0         2.0      55.0
# 13  32.0     90.0         90    60M  285K       2.0         4.0      84.0
#
#     Finishing  HeadingAccuracy  ...  LongShots  Aggression  Interceptions  \
# 9        11.0             15.0  ...       12.0        34.0           19.0
# 10       91.0             85.0  ...       84.0        80.0           39.0
# 11       76.0             54.0  ...       92.0        60.0           82.0
# 12       42.0             92.0  ...       43.0        89.0           88.0
# 13       76.0             54.0  ...       75.0        57.0           50.0
#
#     Positioning  Vision  Penalties  Composure  Marking  StandingTackle  \
# 9          11.0    70.0       11.0       70.0     27.0            12.0
# 10         91.0    77.0       88.0       86.0     34.0            42.0
# 11         79.0    86.0       73.0       85.0     72.0            79.0
# 12         48.0    52.0       50.0       82.0     90.0            89.0
# 13         89.0    92.0       75.0       93.0     59.0            53.0
#
#     SlidingTackle
# 9            18.0
# 10           19.0
# 11           69.0
# 12           89.0
# 13           29.0
#
# [5 rows x 36 columns]

# %%
df.describe()
# Out:
#                 Age       Overall     Potential      WeakFoot    SkillMoves  \
# count  18196.000000  18197.000000  18197.000000  18149.000000  18149.000000
# mean      25.119807     66.224817     71.295818      2.946719      2.360736
# std        4.669905      6.885312      6.118538      0.660009      0.755308
# min       16.000000     46.000000     48.000000      1.000000      1.000000
# 25%       21.000000     62.000000     67.000000      3.000000      2.000000
# 50%       25.000000     66.000000     71.000000      3.000000      2.000000
# 75%       28.000000     71.000000     75.000000      3.000000      3.000000
# max       45.000000     90.000000     95.000000      5.000000      5.000000
#
#            Crossing     Finishing  HeadingAccuracy  ShortPassing  \
# count  18149.000000  18149.000000     18149.000000  18149.000000
# mean      49.724007     45.537771        52.294341     58.676346
# std       18.353592     19.510685        17.374173     14.690734
# min        5.000000      2.000000         4.000000      7.000000
# 25%       38.000000     30.000000        44.000000     54.000000
# 50%       54.000000     49.000000        56.000000     62.000000
# 75%       64.000000     62.000000        64.000000     68.000000
# max       92.000000     94.000000        94.000000     93.000000
#
#             Volleys  ...     LongShots    Aggression  Interceptions  \
# count  18149.000000  ...  18149.000000  18149.000000   18149.000000
# mean      42.895421  ...     47.098022     55.865888      46.698937
# std       17.677806  ...     19.245890     17.367921      20.695438
# min        4.000000  ...      3.000000     11.000000       3.000000
# 25%       30.000000  ...     33.000000     44.000000      26.000000
# 50%       44.000000  ...     51.000000     59.000000      52.000000
# 75%       57.000000  ...     62.000000     69.000000      64.000000
# max       90.000000  ...     93.000000     95.000000      92.000000
#
#         Positioning        Vision     Penalties     Composure       Marking  \
# count  18149.000000  18149.000000  18149.000000  18149.000000  18149.000000
# mean      49.947105     53.385035     48.536063     58.633644     47.283487
# std       19.514788     14.132289     15.692254     11.420107     19.902839
# min        2.000000     10.000000      5.000000      3.000000      3.000000
# 25%       38.000000     44.000000     39.000000     51.000000     30.000000
# 50%       55.000000     55.000000     49.000000     60.000000     53.000000
# 75%       64.000000     64.000000     60.000000     67.000000     64.000000
# max       93.000000     93.000000     92.000000     93.000000     94.000000
#
#        StandingTackle  SlidingTackle
# count    18149.000000   18149.000000
# mean        47.701251      45.665657
# std         21.661768      21.286136
# min          2.000000       3.000000
# 25%         27.000000      24.000000
# 50%         55.000000      52.000000
# 75%         66.000000      64.000000
# max         93.000000      90.000000
#
# [8 rows x 34 columns]

# %%
#Getting rid of all the elements that makes difficult to convert the different columns datatypes
df['Value'] = df['Value'].str.replace('€', '')
df['Value'] = df['Value'].str.replace('K', '000')
df['Value'] = df['Value'].str.replace('M', '')
df['Wage'] = df['Wage'].str.replace('€', '')
df['Wage'] = df['Wage'].str.replace('K', '')

df.dtypes
# Out:
# Age                float64
# Overall            float64
# Potential            int64
# Value               object
# Wage                object
# WeakFoot           float64
# SkillMoves         float64
# Crossing           float64
# Finishing          float64
# HeadingAccuracy    float64
# ShortPassing       float64
# Volleys            float64
# Dribbling          float64
# Curve              float64
# FKAccuracy         float64
# LongPassing        float64
# BallControl        float64
# Acceleration       float64
# SprintSpeed        float64
# Agility            float64
# Reactions          float64
# Balance            float64
# ShotPower          float64
# Jumping            float64
# Stamina            float64
# Strength           float64
# LongShots          float64
# Aggression         float64
# Interceptions      float64
# Positioning        float64
# Vision             float64
# Penalties          float64
# Composure          float64
# Marking            float64
# StandingTackle     float64
# SlidingTackle      float64
# dtype: object

# %%
#Coverting value and wage to a float
df['Value'] = df['Value'].replace({'\x80':''}, regex=True).astype('float64')
df['Wage'] = df['Wage'].replace({'\x80':''}, regex=True).astype('float64')

df.shape
# Out:
# (18197, 36)

# %%
#checking the data for null values
df.isnull().sum()
# Out:
# Age                 1
# Overall             0
# Potential           0
# Value               0
# Wage                0
# WeakFoot           48
# SkillMoves         48
# Crossing           48
# Finishing          48
# HeadingAccuracy    48
# ShortPassing       48
# Volleys            48
# Dribbling          48
# Curve              48
# FKAccuracy         48
# LongPassing        48
# BallControl        48
# Acceleration       48
# SprintSpeed        48
# Agility            48
# Reactions          48
# Balance            48
# ShotPower          48
# Jumping            48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# Composure          48
# Marking            48
# StandingTackle     48
# SlidingTackle      48
# dtype: int64

# %%
#removing null values
df = df.dropna()
df
# Out:
#         Age  Overall  Potential    Value   Wage  WeakFoot  SkillMoves  \
# 9      25.0     90.0         93     68.0   94.0       3.0         1.0
# 10     29.0     90.0         90     77.0  205.0       4.0         4.0
# 12     32.0     90.0         90     44.0  125.0       3.0         2.0
# 13     32.0     90.0         90     60.0  285.0       2.0         4.0
# 14     27.0     89.0         90     63.0  225.0       3.0         2.0
# ...     ...      ...        ...      ...    ...       ...         ...
# 18202  19.0     47.0         65  60000.0    1.0       2.0         2.0
# 18203  19.0     47.0         63  60000.0    1.0       2.0         2.0
# 18204  16.0     47.0         67  60000.0    1.0       3.0         2.0
# 18205  17.0     47.0         66  60000.0    1.0       3.0         2.0
# 18206  16.0     46.0         66  60000.0    1.0       3.0         2.0
#
#        Crossing  Finishing  HeadingAccuracy  ...  LongShots  Aggression  \
# 9          13.0       11.0             15.0  ...       12.0        34.0
# 10         62.0       91.0             85.0  ...       84.0        80.0
# 12         55.0       42.0             92.0  ...       43.0        89.0
# 13         84.0       76.0             54.0  ...       75.0        57.0
# 14         68.0       65.0             54.0  ...       69.0        90.0
# ...         ...        ...              ...  ...        ...         ...
# 18202      34.0       38.0             40.0  ...       38.0        46.0
# 18203      23.0       52.0             52.0  ...       42.0        47.0
# 18204      25.0       40.0             46.0  ...       45.0        32.0
# 18205      44.0       50.0             39.0  ...       34.0        33.0
# 18206      41.0       34.0             46.0  ...       32.0        56.0
#
#        Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 9               19.0         11.0    70.0       11.0       70.0     27.0
# 10              39.0         91.0    77.0       88.0       86.0     34.0
# 12              88.0         48.0    52.0       50.0       82.0     90.0
# 13              50.0         89.0    92.0       75.0       93.0     59.0
# 14              92.0         71.0    79.0       54.0       85.0     90.0
# ...              ...          ...     ...        ...        ...      ...
# 18202           46.0         39.0    52.0       43.0       45.0     40.0
# 18203           16.0         46.0    33.0       43.0       42.0     22.0
# 18204           15.0         48.0    43.0       55.0       41.0     32.0
# 18205           22.0         44.0    47.0       50.0       46.0     20.0
# 18206           42.0         34.0    49.0       33.0       43.0     40.0
#
#        StandingTackle  SlidingTackle
# 9                12.0           18.0
# 10               42.0           19.0
# 12               89.0           89.0
# 13               53.0           29.0
# 14               91.0           85.0
# ...               ...            ...
# 18202            48.0           47.0
# 18203            15.0           19.0
# 18204            13.0           11.0
# 18205            25.0           27.0
# 18206            43.0           50.0
#
# [18148 rows x 36 columns]

# %%
#Plot showing Number of players by age
plt.hist(df['Age'])
plt.xlabel('Players Age')
plt.ylabel('Number of players')
plt.show()

# %%
#graph showing number of players by overall
plt.hist(df['Overall'])
plt.xlabel('Players Rating')
plt.ylabel('Number of players')
plt.show()

# %%
#graph showing number of players and their porential
plt.hist(df['Potential'])
plt.xlabel('Players Potential')
plt.ylabel('Number of players')
plt.show()

# %%
# Creating a correlation matrix
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),linewidths=4)
plt.title('Dataset Heatmap')
plt.show()

# %%
# Select the features and the target
X = df[['Age','Value','WeakFoot','Potential','Wage','Crossing', 'Finishing', 'HeadingAccuracy', "SkillMoves",
       'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
       'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility',
       'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength',
       'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
       'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle']]

y = df['Overall']

# %%
#Scaling data to ensure all features have the same scale
scaler = StandardScaler()
scaler.fit_transform(X)
# Out:
# array([[-0.02572015, -0.90054693,  0.08092099, ..., -1.01910015,
#         -1.64813782, -1.29968571],
#        [ 0.8307371 , -0.90051608,  1.59645673, ..., -0.6673766 ,
#         -0.26312967, -1.25270522],
#        [ 1.47308004, -0.90062919,  0.08092099, ...,  2.14641187,
#          1.90671643,  2.03592913],
#        ...,
#        [-1.95274895, -0.69512134,  0.08092099, ..., -0.76786904,
#         -1.60197088, -1.62854915],
#        [-1.73863464, -0.69512134,  0.08092099, ..., -1.37082371,
#         -1.04796762, -0.8768613 ],
#        [-1.95274895, -0.69512134,  0.08092099, ..., -0.36589926,
#         -0.21696273,  0.20368999]])

# %%
# Assuming that 'X' is your feature set and 'y' is the target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Define the cross-validation method
cv = RepeatedKFold(n_splits=10, n_repeats=3)

# Define the range of alpha values to try
alphas = np.arange(0.0001, 0.00015, 0.00099)

# Create a Ridge Regression model
ridge = RidgeCV(alphas=alphas, cv=cv)

# %%
# Train the model
ridge.fit(X_train, y_train)

# The alpha_ attribute holds the best alpha value found during cross-validation
print(f'Best alpha: {ridge.alpha_}')
# Out:
# Best alpha: 0.0001

# %%
# Now you can use the trained model to make predictions on your test set
y_pred = ridge.predict(X_test)

# %%
# I want to see the actual value vs the predicted value
for actual, predicted in zip(y_test, y_pred):
     print(f'Actual: {actual}, Predicted: {predicted}')
# Out:
# Actual: 66.0, Predicted: 65.76116578117515
# Actual: 71.0, Predicted: 71.00107185505298
# Actual: 58.0, Predicted: 55.52633317648616
# Actual: 76.0, Predicted: 72.63155256324046
# Actual: 69.0, Predicted: 72.22176056703738
# Actual: 70.0, Predicted: 73.50602383248152
# Actual: 58.0, Predicted: 56.916033998616896
# Actual: 66.0, Predicted: 64.64342251236607
# Actual: 59.0, Predicted: 57.32694772845748
# Actual: 76.0, Predicted: 75.17321679993302
# Actual: 76.0, Predicted: 77.81918751579703
# Actual: 73.0, Predicted: 74.42373014735843
# Actual: 63.0, Predicted: 61.84903178555193
# Actual: 69.0, Predicted: 72.15743892968867
# Actual: 70.0, Predicted: 72.91148899850873
# Actual: 64.0, Predicted: 62.194647072366365
# Actual: 69.0, Predicted: 69.88842191967362
# Actual: 66.0, Predicted: 67.81771347267215
# Actual: 68.0, Predicted: 67.40258514895991
# Actual: 75.0, Predicted: 72.66946517184134
# Actual: 62.0, Predicted: 60.020195547575184
# Actual: 69.0, Predicted: 67.51536576261398
# Actual: 73.0, Predicted: 72.67276823972166
# Actual: 77.0, Predicted: 75.63482268507919
# Actual: 57.0, Predicted: 57.7368771846468
# Actual: 69.0, Predicted: 67.49254381699454
# Actual: 64.0, Predicted: 64.84502680536981
# Actual: 57.0, Predicted: 56.17020414075404
# Actual: 61.0, Predicted: 61.27805842721068
# Actual: 65.0, Predicted: 62.253672007477874
# Actual: 63.0, Predicted: 62.74013045147282
# Actual: 61.0, Predicted: 60.437639202356394
# Actual: 71.0, Predicted: 69.7490544421084
# Actual: 69.0, Predicted: 68.93846283130652
# Actual: 67.0, Predicted: 65.89551041122041
# Actual: 70.0, Predicted: 69.37686465516884
# Actual: 62.0, Predicted: 61.05967967425795
# Actual: 64.0, Predicted: 59.748648593292444
# Actual: 64.0, Predicted: 62.05816895391541
# Actual: 50.0, Predicted: 47.027982274089176
# Actual: 77.0, Predicted: 78.86895783554573
# Actual: 67.0, Predicted: 66.95747652787446
# Actual: 68.0, Predicted: 68.45007357302713
# Actual: 66.0, Predicted: 71.25766233696383
# Actual: 71.0, Predicted: 68.32638373963661
# Actual: 69.0, Predicted: 67.2061647768808
# Actual: 68.0, Predicted: 67.52995678826967
# Actual: 61.0, Predicted: 62.61857263545785
# Actual: 82.0, Predicted: 78.85265308277708
# Actual: 58.0, Predicted: 59.16075738556658
# Actual: 59.0, Predicted: 52.89493270284753
# Actual: 64.0, Predicted: 65.13486300255875
# Actual: 63.0, Predicted: 62.68034745953402
# Actual: 63.0, Predicted: 61.211304680100255
# Actual: 69.0, Predicted: 67.88176624781306
# Actual: 67.0, Predicted: 65.73010293206588
# Actual: 59.0, Predicted: 62.28292027377209
# Actual: 70.0, Predicted: 66.90900555658065
# Actual: 67.0, Predicted: 68.60588429974895
# Actual: 59.0, Predicted: 58.01200286525933
# Actual: 68.0, Predicted: 65.67414804965284
# Actual: 79.0, Predicted: 78.6395176287512
# Actual: 55.0, Predicted: 54.816855924069785
# Actual: 76.0, Predicted: 74.86971269562495
# Actual: 57.0, Predicted: 64.88999659049726
# Actual: 65.0, Predicted: 66.28396507687754
# Actual: 66.0, Predicted: 64.97587030557558
# Actual: 75.0, Predicted: 70.42320007663376
# Actual: 66.0, Predicted: 69.08673996362862
# Actual: 75.0, Predicted: 72.55690937350226
# Actual: 61.0, Predicted: 62.94002748158256
# Actual: 68.0, Predicted: 66.27743613982258
# Actual: 53.0, Predicted: 56.038887535969025
# Actual: 77.0, Predicted: 75.77124867004969
# Actual: 53.0, Predicted: 55.844104440820686
# Actual: 69.0, Predicted: 67.71032692534506
# Actual: 56.0, Predicted: 57.81354038193855
# Actual: 71.0, Predicted: 69.18974873400505
# Actual: 63.0, Predicted: 60.80650199875018
# Actual: 68.0, Predicted: 67.5948741550366
# Actual: 71.0, Predicted: 70.251571636068
# Actual: 60.0, Predicted: 65.95372114220045
# Actual: 74.0, Predicted: 71.46769510102159
# Actual: 53.0, Predicted: 53.08315165786075
# Actual: 68.0, Predicted: 68.24984639767776
# Actual: 62.0, Predicted: 65.28021322423267
# Actual: 77.0, Predicted: 74.8495820763421
# Actual: 55.0, Predicted: 56.90910795019458
# Actual: 72.0, Predicted: 72.25067238812892
# Actual: 72.0, Predicted: 69.30862212300035
# Actual: 57.0, Predicted: 59.24575250739821
# Actual: 65.0, Predicted: 63.00193589286903
# Actual: 67.0, Predicted: 63.47897719051308
# Actual: 70.0, Predicted: 70.88300664847111
# Actual: 61.0, Predicted: 60.53755023440871
# Actual: 66.0, Predicted: 63.4226408655159
# Actual: 58.0, Predicted: 57.59662891464082
# Actual: 80.0, Predicted: 79.11998800300195
# Actual: 65.0, Predicted: 65.45201959923828
# Actual: 62.0, Predicted: 58.36101079363161
# Actual: 53.0, Predicted: 57.89515657085818
# Actual: 63.0, Predicted: 65.46136890718952
# Actual: 62.0, Predicted: 61.08045964649723
# Actual: 65.0, Predicted: 61.331395034086285
# Actual: 65.0, Predicted: 64.23357189795541
# Actual: 72.0, Predicted: 70.40290299491163
# Actual: 63.0, Predicted: 60.16831771493756
# Actual: 60.0, Predicted: 60.256833661473834
# Actual: 73.0, Predicted: 74.3802779801265
# Actual: 70.0, Predicted: 68.68736596327116
# Actual: 64.0, Predicted: 63.42456368948814
# Actual: 59.0, Predicted: 62.84693295922901
# Actual: 61.0, Predicted: 60.55037023490581
# Actual: 59.0, Predicted: 57.40664367535605
# Actual: 62.0, Predicted: 62.527028174655456
# Actual: 65.0, Predicted: 66.82758804809555
# Actual: 68.0, Predicted: 67.7423545360095
# Actual: 71.0, Predicted: 69.34055431892793
# Actual: 60.0, Predicted: 61.022855526479745
# Actual: 65.0, Predicted: 63.641847796573515
# Actual: 67.0, Predicted: 66.12012555307501
# Actual: 63.0, Predicted: 60.84741616372051
# Actual: 69.0, Predicted: 70.6270849135967
# Actual: 65.0, Predicted: 63.76999478092023
# Actual: 61.0, Predicted: 61.83231581684028
# Actual: 60.0, Predicted: 60.712400536650534
# Actual: 59.0, Predicted: 58.58237591028167
# Actual: 64.0, Predicted: 65.19543891771782
# Actual: 60.0, Predicted: 57.772685740822595
# Actual: 61.0, Predicted: 57.77300447672647
# Actual: 69.0, Predicted: 69.37755832335279
# Actual: 60.0, Predicted: 58.02285509221794
# Actual: 70.0, Predicted: 70.7139750814169
# Actual: 67.0, Predicted: 65.20999362586609
# Actual: 54.0, Predicted: 56.29530726741483
# Actual: 50.0, Predicted: 50.175855735665394
# Actual: 76.0, Predicted: 74.20184436953872
# Actual: 73.0, Predicted: 73.55355183906656
# Actual: 72.0, Predicted: 73.90449037969844
# Actual: 63.0, Predicted: 63.250085127429244
# Actual: 75.0, Predicted: 75.3995803192157
# Actual: 66.0, Predicted: 66.33904719199927
# Actual: 72.0, Predicted: 72.21729261473591
# Actual: 64.0, Predicted: 62.40349494533362
# Actual: 63.0, Predicted: 60.418405678167474
# Actual: 75.0, Predicted: 71.5254718201387
# Actual: 71.0, Predicted: 71.75772894367122
# Actual: 80.0, Predicted: 80.4836743868214
# Actual: 68.0, Predicted: 67.10830845350752
# Actual: 68.0, Predicted: 67.69022766249527
# Actual: 55.0, Predicted: 54.149083780042815
# Actual: 59.0, Predicted: 60.2096680981748
# Actual: 63.0, Predicted: 63.386438374703374
# Actual: 55.0, Predicted: 58.774304586747576
# Actual: 62.0, Predicted: 63.63813310376841
# Actual: 67.0, Predicted: 65.60573848789137
# Actual: 77.0, Predicted: 73.14566068865618
# Actual: 63.0, Predicted: 64.14330974403711
# Actual: 54.0, Predicted: 53.74156494982596
# Actual: 72.0, Predicted: 73.35482323888222
# Actual: 64.0, Predicted: 67.71847459929741
# Actual: 63.0, Predicted: 61.26322614179574
# Actual: 66.0, Predicted: 64.3066111314087
# Actual: 76.0, Predicted: 75.54660743082879
# Actual: 69.0, Predicted: 69.27978769189085
# Actual: 70.0, Predicted: 70.34342160761757
# Actual: 74.0, Predicted: 73.09241445111286
# Actual: 58.0, Predicted: 60.817291020023475
# Actual: 63.0, Predicted: 65.5205093254948
# Actual: 64.0, Predicted: 64.07532903196257
# Actual: 61.0, Predicted: 62.302880080907414
# Actual: 82.0, Predicted: 78.22797458424442
# Actual: 74.0, Predicted: 71.1342563945462
# Actual: 79.0, Predicted: 76.6388156618536
# Actual: 68.0, Predicted: 67.93142163504322
# Actual: 63.0, Predicted: 63.06766459673966
# Actual: 62.0, Predicted: 66.89208098621856
# Actual: 61.0, Predicted: 60.25120206283917
# Actual: 60.0, Predicted: 60.162744907218794
# Actual: 66.0, Predicted: 67.3944936212715
# Actual: 70.0, Predicted: 69.30153590367519
# Actual: 66.0, Predicted: 65.52040662942251
# Actual: 69.0, Predicted: 69.10084714290231
# Actual: 66.0, Predicted: 64.67384934890124
# Actual: 58.0, Predicted: 59.740245806603866
# Actual: 57.0, Predicted: 54.88663262047481
# Actual: 73.0, Predicted: 70.75002673900525
# Actual: 61.0, Predicted: 59.94719794772651
# Actual: 54.0, Predicted: 57.31875551294645
# Actual: 73.0, Predicted: 75.48202783109694
# Actual: 67.0, Predicted: 61.96450882234032
# Actual: 67.0, Predicted: 67.27322888268819
# Actual: 77.0, Predicted: 78.53698817265534
# Actual: 58.0, Predicted: 61.06571758867386
# Actual: 80.0, Predicted: 80.29473108496435
# Actual: 70.0, Predicted: 68.72646484208448
# Actual: 70.0, Predicted: 70.28957664743467
# Actual: 68.0, Predicted: 67.38385230717704
# Actual: 70.0, Predicted: 69.576928150037
# Actual: 72.0, Predicted: 70.68866841599078
# Actual: 56.0, Predicted: 55.69666947275364
# Actual: 68.0, Predicted: 69.19802358457508
# Actual: 70.0, Predicted: 70.89181530898523
# Actual: 70.0, Predicted: 68.58029219647011
# Actual: 60.0, Predicted: 58.16521738498999
# Actual: 61.0, Predicted: 59.95968099447924
# Actual: 65.0, Predicted: 64.21644367809743
# Actual: 80.0, Predicted: 75.63729998781366
# Actual: 71.0, Predicted: 69.4125901575667
# Actual: 70.0, Predicted: 67.78854723105246
# Actual: 70.0, Predicted: 66.31910036993158
# Actual: 70.0, Predicted: 68.68802301772833
# Actual: 64.0, Predicted: 61.10179649779994
# Actual: 64.0, Predicted: 62.90551388880438
# Actual: 60.0, Predicted: 67.82974591825095
# Actual: 61.0, Predicted: 59.81302631502521
# Actual: 57.0, Predicted: 62.8607060618736
# Actual: 82.0, Predicted: 80.83641657503922
# Actual: 68.0, Predicted: 66.33927441269203
# Actual: 55.0, Predicted: 57.062198651225515
# Actual: 73.0, Predicted: 74.32369175364781
# Actual: 61.0, Predicted: 63.925631493474086
# Actual: 69.0, Predicted: 69.21753407229426
# Actual: 64.0, Predicted: 63.533778073623736
# Actual: 67.0, Predicted: 68.40689993902863
# Actual: 51.0, Predicted: 51.39025492196896
# Actual: 63.0, Predicted: 60.85840600276218
# Actual: 50.0, Predicted: 53.8926528230528
# Actual: 78.0, Predicted: 78.17778317662714
# Actual: 63.0, Predicted: 66.38464270772495
# Actual: 65.0, Predicted: 64.20681673793975
# Actual: 76.0, Predicted: 75.23194010397042
# Actual: 56.0, Predicted: 60.50782789227894
# Actual: 66.0, Predicted: 63.82932211374846
# Actual: 64.0, Predicted: 61.556211943508586
# Actual: 64.0, Predicted: 62.562768769238005
# Actual: 73.0, Predicted: 73.18889706148178
# Actual: 58.0, Predicted: 57.54423406431813
# Actual: 66.0, Predicted: 63.47838031254845
# Actual: 73.0, Predicted: 73.47851986053303
# Actual: 69.0, Predicted: 66.0266692296678
# Actual: 63.0, Predicted: 66.00390381081608
# Actual: 74.0, Predicted: 71.92622903466446
# Actual: 51.0, Predicted: 52.83498759593088
# Actual: 65.0, Predicted: 67.39240772331998
# Actual: 75.0, Predicted: 74.6661577968597
# Actual: 65.0, Predicted: 63.95668037032553
# Actual: 72.0, Predicted: 72.10976895524331
# Actual: 63.0, Predicted: 64.90963121320692
# Actual: 81.0, Predicted: 80.19444784273666
# Actual: 66.0, Predicted: 67.67967012996633
# Actual: 60.0, Predicted: 59.87785623003961
# Actual: 81.0, Predicted: 82.02358195529918
# Actual: 59.0, Predicted: 56.48769592676058
# Actual: 72.0, Predicted: 72.76774614116728
# Actual: 63.0, Predicted: 61.7313461135458
# Actual: 68.0, Predicted: 66.77831490896567
# Actual: 57.0, Predicted: 61.40687081268585
# Actual: 76.0, Predicted: 76.50609207787966
# Actual: 70.0, Predicted: 69.27452789655806
# Actual: 72.0, Predicted: 70.14163232573917
# Actual: 65.0, Predicted: 64.40811249387588
# Actual: 73.0, Predicted: 72.86237849441443
# Actual: 68.0, Predicted: 67.11002648120949
# Actual: 63.0, Predicted: 64.62475215349471
# Actual: 68.0, Predicted: 70.9840741915192
# Actual: 52.0, Predicted: 52.58640539365036
# Actual: 65.0, Predicted: 64.35250109889063
# Actual: 72.0, Predicted: 73.29180795045846
# Actual: 68.0, Predicted: 67.76340961405981
# Actual: 74.0, Predicted: 74.3431646943013
# Actual: 65.0, Predicted: 63.7030614821298
# Actual: 77.0, Predicted: 75.89715885630707
# Actual: 66.0, Predicted: 65.45222207038181
# Actual: 64.0, Predicted: 62.436156059284826
# Actual: 62.0, Predicted: 60.729854447700944
# Actual: 68.0, Predicted: 66.71200179052265
# Actual: 52.0, Predicted: 54.85159406259605
# Actual: 63.0, Predicted: 63.55223204218295
# Actual: 65.0, Predicted: 66.87810029834702
# Actual: 59.0, Predicted: 60.012802277768486
# Actual: 77.0, Predicted: 73.7114564320479
# Actual: 59.0, Predicted: 55.734249163903286
# Actual: 60.0, Predicted: 58.35354396377738
# Actual: 72.0, Predicted: 73.17561009997823
# Actual: 64.0, Predicted: 63.10890443683408
# Actual: 74.0, Predicted: 74.72523673715031
# Actual: 72.0, Predicted: 70.59734867852211
# Actual: 67.0, Predicted: 67.02420231768193
# Actual: 70.0, Predicted: 73.13638478468464
# Actual: 74.0, Predicted: 73.34771824663385
# Actual: 55.0, Predicted: 56.78799918603222
# Actual: 67.0, Predicted: 65.17588401344781
# Actual: 75.0, Predicted: 78.0003830714238
# Actual: 71.0, Predicted: 70.61527514144156
# Actual: 63.0, Predicted: 63.132313728898936
# Actual: 69.0, Predicted: 67.23324645092943
# Actual: 60.0, Predicted: 59.090835423382416
# Actual: 60.0, Predicted: 60.21016447206877
# Actual: 66.0, Predicted: 67.81741216849133
# Actual: 56.0, Predicted: 56.55420984844085
# Actual: 67.0, Predicted: 69.01021702757556
# Actual: 63.0, Predicted: 60.59244809209994
# Actual: 62.0, Predicted: 64.57717885835709
# Actual: 63.0, Predicted: 64.72229193813365
# Actual: 63.0, Predicted: 65.01860070681562
# Actual: 71.0, Predicted: 71.8790492974946
# Actual: 62.0, Predicted: 60.679549378535526
# Actual: 62.0, Predicted: 59.825199730602876
# Actual: 63.0, Predicted: 62.43749977085187
# Actual: 64.0, Predicted: 62.25669115400093
# Actual: 76.0, Predicted: 77.68211392669946
# Actual: 61.0, Predicted: 61.13711286862677
# Actual: 78.0, Predicted: 73.485665714457
# Actual: 80.0, Predicted: 76.17910184891412
# Actual: 79.0, Predicted: 78.00139009862136
# Actual: 65.0, Predicted: 64.35750113695248
# Actual: 72.0, Predicted: 72.45557952650768
# Actual: 74.0, Predicted: 72.62623162674556
# Actual: 69.0, Predicted: 68.3090848634456
# Actual: 72.0, Predicted: 73.06890913258835
# Actual: 66.0, Predicted: 65.27589097603165
# Actual: 64.0, Predicted: 62.424382964652295
# Actual: 67.0, Predicted: 63.50710838317379
# Actual: 74.0, Predicted: 72.4112832864495
# Actual: 58.0, Predicted: 60.158757321283716
# Actual: 70.0, Predicted: 67.47436600396955
# Actual: 68.0, Predicted: 68.03159730960844
# Actual: 67.0, Predicted: 69.0640108863941
# Actual: 67.0, Predicted: 65.68493412948072
# Actual: 63.0, Predicted: 64.90544600239599
# Actual: 64.0, Predicted: 64.49879195309255
# Actual: 72.0, Predicted: 68.44506288915727
# Actual: 67.0, Predicted: 67.2298091747841
# Actual: 63.0, Predicted: 60.11898319417658
# Actual: 84.0, Predicted: 85.11158909736687
# Actual: 54.0, Predicted: 57.28785902006476
# Actual: 77.0, Predicted: 77.90185324273024
# Actual: 65.0, Predicted: 65.91390103870611
# Actual: 66.0, Predicted: 66.7280111338799
# Actual: 72.0, Predicted: 68.80528236675505
# Actual: 64.0, Predicted: 67.4760062759958
# Actual: 63.0, Predicted: 63.399965755001105
# Actual: 60.0, Predicted: 61.17773580979201
# Actual: 55.0, Predicted: 53.74358106783434
# Actual: 62.0, Predicted: 60.93902145494597
# Actual: 68.0, Predicted: 72.07618596603518
# Actual: 56.0, Predicted: 60.399607957875574
# Actual: 76.0, Predicted: 74.95542864178874
# Actual: 65.0, Predicted: 64.21459453550432
# Actual: 68.0, Predicted: 66.39656881464
# Actual: 68.0, Predicted: 67.71364709343864
# Actual: 67.0, Predicted: 70.3765386057973
# Actual: 73.0, Predicted: 75.8897955823329
# Actual: 67.0, Predicted: 65.21126161113348
# Actual: 67.0, Predicted: 66.00109124043257
# Actual: 65.0, Predicted: 65.21532389898248
# Actual: 66.0, Predicted: 69.17998843433288
# Actual: 72.0, Predicted: 72.28877069754888
# Actual: 58.0, Predicted: 58.01641237430371
# Actual: 66.0, Predicted: 65.13840731379479
# Actual: 75.0, Predicted: 75.69832407997285
# Actual: 88.0, Predicted: 88.94614004428206
# Actual: 69.0, Predicted: 68.45006938313095
# Actual: 77.0, Predicted: 76.23006459883655
# Actual: 72.0, Predicted: 72.54943578584015
# Actual: 66.0, Predicted: 61.632659947372034
# Actual: 65.0, Predicted: 67.6461279791041
# Actual: 67.0, Predicted: 65.10362642912445
# Actual: 73.0, Predicted: 73.2200759471932
# Actual: 67.0, Predicted: 67.69549860831812
# Actual: 66.0, Predicted: 66.05651291590576
# Actual: 65.0, Predicted: 63.17812844417283
# Actual: 62.0, Predicted: 65.30322546352653
# Actual: 57.0, Predicted: 58.02807637179221
# Actual: 76.0, Predicted: 73.84724467655961
# Actual: 65.0, Predicted: 66.37625510798941
# Actual: 69.0, Predicted: 67.00329012137871
# Actual: 75.0, Predicted: 75.29154135317447
# Actual: 64.0, Predicted: 66.2385214534627
# Actual: 63.0, Predicted: 64.57545436933697
# Actual: 69.0, Predicted: 67.7858752657379
# Actual: 77.0, Predicted: 77.34557625859404
# Actual: 74.0, Predicted: 72.13209085752537
# Actual: 76.0, Predicted: 76.05612315402097
# Actual: 62.0, Predicted: 63.08450233892411
# Actual: 57.0, Predicted: 55.29080129866098
# Actual: 59.0, Predicted: 57.89650388207592
# Actual: 83.0, Predicted: 85.55657227247949
# Actual: 75.0, Predicted: 74.62313127381728
# Actual: 77.0, Predicted: 75.64458305658334
# Actual: 63.0, Predicted: 65.4262017103471
# Actual: 68.0, Predicted: 69.68601780422402
# Actual: 76.0, Predicted: 77.52119288718399
# Actual: 58.0, Predicted: 58.39350452617728
# Actual: 80.0, Predicted: 81.04532534638817
# Actual: 72.0, Predicted: 72.4967874474486
# Actual: 70.0, Predicted: 67.57919846020468
# Actual: 61.0, Predicted: 62.78096108663628
# Actual: 68.0, Predicted: 65.8822890753332
# Actual: 50.0, Predicted: 51.18395771283407
# Actual: 54.0, Predicted: 58.219855232951815
# Actual: 74.0, Predicted: 73.26612149338915
# Actual: 67.0, Predicted: 65.37173406302854
# Actual: 61.0, Predicted: 63.70865397562078
# Actual: 60.0, Predicted: 61.614476691665345
# Actual: 64.0, Predicted: 65.15230326836439
# Actual: 68.0, Predicted: 66.86069666953274
# Actual: 70.0, Predicted: 68.35928237046512
# Actual: 65.0, Predicted: 68.69189877040583
# Actual: 62.0, Predicted: 63.536915755506726
# Actual: 64.0, Predicted: 65.40957009037858
# Actual: 67.0, Predicted: 65.68273310019465
# Actual: 69.0, Predicted: 66.75816508669847
# Actual: 65.0, Predicted: 64.55560058874268
# Actual: 64.0, Predicted: 63.70195039846496
# Actual: 64.0, Predicted: 62.05017863436126
# Actual: 61.0, Predicted: 60.42226913962783
# Actual: 58.0, Predicted: 55.89236390009782
# Actual: 66.0, Predicted: 67.96777473295532
# Actual: 61.0, Predicted: 60.08596756546699
# Actual: 61.0, Predicted: 61.56400447378883
# Actual: 56.0, Predicted: 55.03790933264179
# Actual: 73.0, Predicted: 71.40059705412544
# Actual: 69.0, Predicted: 67.51169294682799
# Actual: 63.0, Predicted: 62.85558878623024
# Actual: 69.0, Predicted: 69.24243304231462
# Actual: 67.0, Predicted: 66.88541208915342
# Actual: 52.0, Predicted: 55.87422173518479
# Actual: 59.0, Predicted: 60.36983728986601
# Actual: 71.0, Predicted: 70.23496788030057
# Actual: 70.0, Predicted: 68.94961812301207
# Actual: 72.0, Predicted: 68.66863500571584
# Actual: 66.0, Predicted: 64.04363243979806
# Actual: 61.0, Predicted: 59.93365387186813
# Actual: 71.0, Predicted: 69.3785564556795
# Actual: 73.0, Predicted: 71.22460399309695
# Actual: 75.0, Predicted: 77.65970352720977
# Actual: 71.0, Predicted: 70.04781111302106
# Actual: 62.0, Predicted: 64.0882086186727
# Actual: 72.0, Predicted: 70.20476979796578
# Actual: 72.0, Predicted: 70.37528392288621
# Actual: 68.0, Predicted: 65.72347713755167
# Actual: 73.0, Predicted: 72.82677169413124
# Actual: 62.0, Predicted: 61.02770601904905
# Actual: 65.0, Predicted: 65.15277703283894
# Actual: 63.0, Predicted: 62.646535330039825
# Actual: 64.0, Predicted: 65.66624841226546
# Actual: 70.0, Predicted: 66.50502223508524
# Actual: 74.0, Predicted: 73.09290433653297
# Actual: 69.0, Predicted: 66.2416744321266
# Actual: 52.0, Predicted: 54.65692381919263
# Actual: 63.0, Predicted: 62.68594827174479
# Actual: 65.0, Predicted: 66.2669209310154
# Actual: 80.0, Predicted: 80.33969527411644
# Actual: 58.0, Predicted: 60.45256499584768
# Actual: 67.0, Predicted: 66.04901233619002
# Actual: 56.0, Predicted: 55.69220639274043
# Actual: 54.0, Predicted: 53.08895710215887
# Actual: 71.0, Predicted: 71.8963378551614
# Actual: 57.0, Predicted: 59.012564893375455
# Actual: 67.0, Predicted: 66.76238431876499
# Actual: 62.0, Predicted: 61.84040042807648
# Actual: 70.0, Predicted: 68.19680767396015
# Actual: 67.0, Predicted: 65.78101202320357
# Actual: 61.0, Predicted: 62.37290093477968
# Actual: 65.0, Predicted: 65.40711122196083
# Actual: 50.0, Predicted: 52.840058404077325
# Actual: 62.0, Predicted: 60.009429564442684
# Actual: 65.0, Predicted: 64.45366274505905
# Actual: 63.0, Predicted: 58.67955963577536
# Actual: 60.0, Predicted: 63.07613308946557
# Actual: 67.0, Predicted: 67.81422713299493
# Actual: 74.0, Predicted: 73.95231451866071
# Actual: 70.0, Predicted: 71.48940416558553
# Actual: 62.0, Predicted: 61.739153676282015
# Actual: 54.0, Predicted: 55.109275437039884
# Actual: 71.0, Predicted: 71.18680220926187
# Actual: 65.0, Predicted: 65.17534995470304
# Actual: 61.0, Predicted: 65.02522992511632
# Actual: 72.0, Predicted: 69.51258581978571
# Actual: 70.0, Predicted: 68.63343487126163
# Actual: 67.0, Predicted: 66.24068733273084
# Actual: 60.0, Predicted: 60.86668886333527
# Actual: 68.0, Predicted: 65.27923473774626
# Actual: 65.0, Predicted: 66.29912119819218
# Actual: 80.0, Predicted: 77.55294474343327
# Actual: 64.0, Predicted: 63.706066438844985
# Actual: 71.0, Predicted: 71.34202309186162
# Actual: 65.0, Predicted: 65.90301975661319
# Actual: 58.0, Predicted: 58.95736982452472
# Actual: 71.0, Predicted: 72.17946376449001
# Actual: 66.0, Predicted: 66.60865315804172
# Actual: 74.0, Predicted: 74.58125605355022
# Actual: 64.0, Predicted: 64.63613555848208
# Actual: 65.0, Predicted: 64.76419176307463
# Actual: 51.0, Predicted: 57.05192303836529
# Actual: 70.0, Predicted: 71.71689759199873
# Actual: 71.0, Predicted: 68.87755465804545
# Actual: 66.0, Predicted: 67.48209915371599
# Actual: 68.0, Predicted: 68.45170686690317
# Actual: 61.0, Predicted: 62.474998286589795
# Actual: 70.0, Predicted: 68.42821614767027
# Actual: 66.0, Predicted: 66.8456941330632
# Actual: 61.0, Predicted: 60.78642593971733
# Actual: 59.0, Predicted: 63.93367804211461
# Actual: 73.0, Predicted: 70.43616171460873
# Actual: 65.0, Predicted: 62.68817005005383
# Actual: 55.0, Predicted: 56.275972075956886
# Actual: 65.0, Predicted: 65.30700053224538
# Actual: 64.0, Predicted: 62.18870012595367
# Actual: 71.0, Predicted: 70.069939537666
# Actual: 65.0, Predicted: 65.93155860922205
# Actual: 65.0, Predicted: 66.68196411018916
# Actual: 69.0, Predicted: 70.74120863287705
# Actual: 64.0, Predicted: 62.91362157801447
# Actual: 65.0, Predicted: 63.54221594787862
# Actual: 54.0, Predicted: 54.92754376990436
# Actual: 69.0, Predicted: 66.77536095606615
# Actual: 61.0, Predicted: 62.83775322255008
# Actual: 75.0, Predicted: 74.43393287046841
# Actual: 67.0, Predicted: 68.13476699584923
# Actual: 59.0, Predicted: 62.549323784643875
# Actual: 73.0, Predicted: 72.40511260824961
# Actual: 74.0, Predicted: 72.82655964774601
# Actual: 64.0, Predicted: 63.500487971259176
# Actual: 73.0, Predicted: 73.583368598467
# Actual: 59.0, Predicted: 60.443903190374726
# Actual: 71.0, Predicted: 71.96891652300637
# Actual: 66.0, Predicted: 67.06073741506543
# Actual: 63.0, Predicted: 61.252210946709184
# Actual: 67.0, Predicted: 66.6758886080488
# Actual: 50.0, Predicted: 52.29777821558082
# Actual: 64.0, Predicted: 65.57297474883266
# Actual: 54.0, Predicted: 56.17727122662217
# Actual: 63.0, Predicted: 60.152966425753476
# Actual: 61.0, Predicted: 63.74958041480815
# Actual: 77.0, Predicted: 76.98914401465883
# Actual: 71.0, Predicted: 68.24847516253072
# Actual: 52.0, Predicted: 54.60913535347173
# Actual: 62.0, Predicted: 62.26687389869409
# Actual: 60.0, Predicted: 58.40887833265104
# Actual: 76.0, Predicted: 80.20742011719001
# Actual: 71.0, Predicted: 71.29120260554332
# Actual: 52.0, Predicted: 55.05361648472851
# Actual: 73.0, Predicted: 73.54438444160449
# Actual: 67.0, Predicted: 65.55494303089716
# Actual: 70.0, Predicted: 68.73466342694543
# Actual: 80.0, Predicted: 78.0706484700016
# Actual: 61.0, Predicted: 61.51414672347033
# Actual: 69.0, Predicted: 66.7205033047044
# Actual: 61.0, Predicted: 62.61464725720367
# Actual: 71.0, Predicted: 70.92282137871524
# Actual: 76.0, Predicted: 74.94810724577829
# Actual: 64.0, Predicted: 62.42058021863876
# Actual: 71.0, Predicted: 68.46115533792302
# Actual: 71.0, Predicted: 70.35616352767717
# Actual: 62.0, Predicted: 63.05821879993664
# Actual: 65.0, Predicted: 63.00589349084049
# Actual: 67.0, Predicted: 67.50601611416229
# Actual: 61.0, Predicted: 59.16586344317666
# Actual: 82.0, Predicted: 80.11048907118078
# Actual: 77.0, Predicted: 75.99091724262068
# Actual: 60.0, Predicted: 57.96229698608998
# Actual: 64.0, Predicted: 65.16426720280221
# Actual: 65.0, Predicted: 63.986911823215436
# Actual: 56.0, Predicted: 62.539485288861385
# Actual: 65.0, Predicted: 63.28430350145244
# Actual: 57.0, Predicted: 54.9519339089359
# Actual: 60.0, Predicted: 58.67811591761884
# Actual: 62.0, Predicted: 61.95206510922597
# Actual: 73.0, Predicted: 72.93436937642039
# Actual: 61.0, Predicted: 64.01569605263575
# Actual: 83.0, Predicted: 84.58730813345606
# Actual: 62.0, Predicted: 60.36176829301539
# Actual: 69.0, Predicted: 68.52223953127243
# Actual: 62.0, Predicted: 61.95572883888434
# Actual: 68.0, Predicted: 68.91241387190398
# Actual: 67.0, Predicted: 70.39878068189883
# Actual: 70.0, Predicted: 69.51096859679673
# Actual: 68.0, Predicted: 66.97603731655978
# Actual: 76.0, Predicted: 73.633028439132
# Actual: 76.0, Predicted: 73.3522572888817
# Actual: 66.0, Predicted: 64.63309010372961
# Actual: 63.0, Predicted: 63.42666328126319
# Actual: 72.0, Predicted: 70.90343755958932
# Actual: 67.0, Predicted: 67.0372745317742
# Actual: 77.0, Predicted: 75.92109434644492
# Actual: 67.0, Predicted: 64.93858750652132
# Actual: 67.0, Predicted: 65.91056483330239
# Actual: 65.0, Predicted: 63.52125663588478
# Actual: 51.0, Predicted: 49.603825547683414
# Actual: 67.0, Predicted: 65.80057571947746
# Actual: 69.0, Predicted: 65.12107251262199
# Actual: 63.0, Predicted: 61.27870308575994
# Actual: 74.0, Predicted: 73.45782055988603
# Actual: 63.0, Predicted: 62.320871192754026
# Actual: 71.0, Predicted: 70.73982375013402
# Actual: 64.0, Predicted: 65.68615952743059
# Actual: 58.0, Predicted: 59.1009312968915
# Actual: 65.0, Predicted: 66.47662399008738
# Actual: 50.0, Predicted: 54.2832807735021
# Actual: 61.0, Predicted: 61.810189280830414
# Actual: 71.0, Predicted: 71.51716494925715
# Actual: 67.0, Predicted: 67.38451221642687
# Actual: 65.0, Predicted: 66.85975958684323
# Actual: 81.0, Predicted: 82.22353777280712
# Actual: 67.0, Predicted: 67.07708802902903
# Actual: 61.0, Predicted: 58.768391816942184
# Actual: 84.0, Predicted: 85.47121988331796
# Actual: 81.0, Predicted: 79.02667786790012
# Actual: 63.0, Predicted: 68.36263355481735
# Actual: 75.0, Predicted: 72.79856197225587
# Actual: 74.0, Predicted: 73.57154407737073
# Actual: 59.0, Predicted: 57.903431417820286
# Actual: 71.0, Predicted: 69.66805421950613
# Actual: 65.0, Predicted: 64.67799154560039
# Actual: 63.0, Predicted: 62.11872154494107
# Actual: 65.0, Predicted: 63.27123803927846
# Actual: 73.0, Predicted: 69.82480906818343
# Actual: 73.0, Predicted: 74.32857610597955
# Actual: 67.0, Predicted: 65.95555725928898
# Actual: 66.0, Predicted: 64.73340197521433
# Actual: 62.0, Predicted: 65.1510925048542
# Actual: 58.0, Predicted: 61.2409943882364
# Actual: 77.0, Predicted: 73.83505983222256
# Actual: 65.0, Predicted: 63.59220287113938
# Actual: 71.0, Predicted: 66.56252098458846
# Actual: 63.0, Predicted: 62.99163184161462
# Actual: 70.0, Predicted: 69.15540170370458
# Actual: 64.0, Predicted: 66.8828178340453
# Actual: 63.0, Predicted: 63.36186835746517
# Actual: 67.0, Predicted: 67.26318820115442
# Actual: 80.0, Predicted: 78.78792534320235
# Actual: 63.0, Predicted: 62.36506537753358
# Actual: 70.0, Predicted: 71.25373673846664
# Actual: 54.0, Predicted: 54.23244562072236
# Actual: 64.0, Predicted: 60.48355788612729
# Actual: 69.0, Predicted: 66.76948883138984
# Actual: 75.0, Predicted: 71.28674307209471
# Actual: 62.0, Predicted: 60.5908887983951
# Actual: 67.0, Predicted: 65.7908204690269
# Actual: 63.0, Predicted: 62.04583343948002
# Actual: 75.0, Predicted: 74.33634727417201
# Actual: 75.0, Predicted: 76.19042917675021
# Actual: 61.0, Predicted: 61.49676604573642
# Actual: 65.0, Predicted: 62.27887290043786
# Actual: 70.0, Predicted: 70.58548237755946
# Actual: 74.0, Predicted: 71.75854004749509
# Actual: 77.0, Predicted: 77.75365394341497
# Actual: 65.0, Predicted: 64.20130380866445
# Actual: 58.0, Predicted: 57.60604016452976
# Actual: 66.0, Predicted: 66.95147582924074
# Actual: 60.0, Predicted: 60.54840240764129
# Actual: 65.0, Predicted: 63.07589287473533
# Actual: 64.0, Predicted: 62.72873885809666
# Actual: 54.0, Predicted: 55.158867438776014
# Actual: 67.0, Predicted: 66.05676600952809
# Actual: 71.0, Predicted: 71.39664773026459
# Actual: 70.0, Predicted: 71.72562405026572
# Actual: 67.0, Predicted: 66.3455306153517
# Actual: 60.0, Predicted: 61.05831673187336
# Actual: 64.0, Predicted: 63.99141496167148
# Actual: 68.0, Predicted: 67.25612134398185
# Actual: 64.0, Predicted: 63.82479092411852
# Actual: 58.0, Predicted: 62.750588728052676
# Actual: 50.0, Predicted: 50.04373814975303
# Actual: 64.0, Predicted: 63.467877972405134
# Actual: 65.0, Predicted: 62.89422247060239
# Actual: 66.0, Predicted: 63.39945111160338
# Actual: 72.0, Predicted: 72.47394963200941
# Actual: 69.0, Predicted: 71.77336671898057
# Actual: 75.0, Predicted: 74.4791608053519
# Actual: 50.0, Predicted: 50.513449541420954
# Actual: 69.0, Predicted: 67.57802406437328
# Actual: 64.0, Predicted: 67.571114191387
# Actual: 52.0, Predicted: 54.986314905925
# Actual: 74.0, Predicted: 72.51880227469019
# Actual: 63.0, Predicted: 64.09918167809273
# Actual: 47.0, Predicted: 54.497410673594786
# Actual: 70.0, Predicted: 67.12712854437986
# Actual: 69.0, Predicted: 64.42039516727661
# Actual: 65.0, Predicted: 64.87181734247912
# Actual: 75.0, Predicted: 74.89108866694238
# Actual: 69.0, Predicted: 73.24237485920992
# Actual: 63.0, Predicted: 63.798255830715206
# Actual: 58.0, Predicted: 59.60379452804865
# Actual: 67.0, Predicted: 67.33411863102448
# Actual: 60.0, Predicted: 58.85988454373674
# Actual: 78.0, Predicted: 75.68458822717041
# Actual: 74.0, Predicted: 72.08736251274534
# Actual: 62.0, Predicted: 65.05950995460921
# Actual: 65.0, Predicted: 63.66646672840636
# Actual: 60.0, Predicted: 59.32440559871266
# Actual: 67.0, Predicted: 64.45150510415995
# Actual: 71.0, Predicted: 70.71429250391218
# Actual: 60.0, Predicted: 60.471646343043986
# Actual: 76.0, Predicted: 72.5120246526161
# Actual: 73.0, Predicted: 72.61127093661698
# Actual: 60.0, Predicted: 58.3120713516076
# Actual: 70.0, Predicted: 68.74611448901894
# Actual: 65.0, Predicted: 66.66652723839049
# Actual: 66.0, Predicted: 62.35610416102354
# Actual: 66.0, Predicted: 64.49670106801506
# Actual: 65.0, Predicted: 67.45096105855794
# Actual: 71.0, Predicted: 69.38645383591529
# Actual: 66.0, Predicted: 66.36346397824826
# Actual: 67.0, Predicted: 66.33577283783326
# Actual: 73.0, Predicted: 75.21000277294091
# Actual: 54.0, Predicted: 53.436756943750055
# Actual: 60.0, Predicted: 60.401690130087275
# Actual: 66.0, Predicted: 63.87381359029894
# Actual: 62.0, Predicted: 61.1868161944826
# Actual: 65.0, Predicted: 63.07161396246288
# Actual: 68.0, Predicted: 66.98059056941163
# Actual: 74.0, Predicted: 71.59747119753247
# Actual: 68.0, Predicted: 68.44794366010123
# Actual: 68.0, Predicted: 67.26348918849331
# Actual: 64.0, Predicted: 68.08586197481806
# Actual: 68.0, Predicted: 67.20087857949073
# Actual: 70.0, Predicted: 71.6079584171382
# Actual: 67.0, Predicted: 66.21501947523933
# Actual: 62.0, Predicted: 60.89676462609974
# Actual: 69.0, Predicted: 67.56444407652646
# Actual: 68.0, Predicted: 69.62443264615592
# Actual: 68.0, Predicted: 64.75180190071008
# Actual: 67.0, Predicted: 69.6370511167298
# Actual: 73.0, Predicted: 71.36751722903333
# Actual: 62.0, Predicted: 57.80560731317189
# Actual: 72.0, Predicted: 71.52164005647327
# Actual: 69.0, Predicted: 68.33208206872415
# Actual: 66.0, Predicted: 64.24530969110697
# Actual: 61.0, Predicted: 64.02880416225744
# Actual: 66.0, Predicted: 63.28519632108038
# Actual: 70.0, Predicted: 68.87835759962886
# Actual: 64.0, Predicted: 63.53893228028578
# Actual: 65.0, Predicted: 65.17220331238224
# Actual: 75.0, Predicted: 75.3049668295686
# Actual: 69.0, Predicted: 68.59820187551216
# Actual: 56.0, Predicted: 56.49574264345682
# Actual: 84.0, Predicted: 85.149435819596
# Actual: 71.0, Predicted: 69.42385366211904
# Actual: 66.0, Predicted: 63.01714241805004
# Actual: 71.0, Predicted: 69.37757965988439
# Actual: 66.0, Predicted: 66.09561482823904
# Actual: 66.0, Predicted: 65.32754943778359
# Actual: 66.0, Predicted: 66.8334675844855
# Actual: 67.0, Predicted: 65.26019620918639
# Actual: 59.0, Predicted: 56.43960047763467
# Actual: 72.0, Predicted: 71.25303977614944
# Actual: 50.0, Predicted: 52.7293178459804
# Actual: 56.0, Predicted: 55.58030975799143
# Actual: 66.0, Predicted: 64.77408550586854
# Actual: 61.0, Predicted: 59.25813697364224
# Actual: 70.0, Predicted: 69.24220601725537
# Actual: 85.0, Predicted: 83.09973949181736
# Actual: 65.0, Predicted: 64.87198737113572
# Actual: 64.0, Predicted: 63.663091275855535
# Actual: 74.0, Predicted: 73.4571224867163
# Actual: 62.0, Predicted: 60.328077414328504
# Actual: 67.0, Predicted: 66.34061330263427
# Actual: 66.0, Predicted: 63.80179866368732
# Actual: 75.0, Predicted: 74.34551057662387
# Actual: 55.0, Predicted: 57.11798442807674
# Actual: 70.0, Predicted: 68.93819350970026
# Actual: 74.0, Predicted: 72.44364368099662
# Actual: 67.0, Predicted: 69.00619788446853
# Actual: 76.0, Predicted: 75.41912036944542
# Actual: 79.0, Predicted: 78.73638336057837
# Actual: 75.0, Predicted: 75.41108271536658
# Actual: 64.0, Predicted: 62.64539450599847
# Actual: 59.0, Predicted: 58.24258005655034
# Actual: 53.0, Predicted: 53.268819511727074
# Actual: 56.0, Predicted: 60.311496954417734
# Actual: 60.0, Predicted: 59.999505767946346
# Actual: 66.0, Predicted: 64.0516490674159
# Actual: 56.0, Predicted: 61.32797664658325
# Actual: 61.0, Predicted: 60.936064107386784
# Actual: 65.0, Predicted: 64.75548312550313
# Actual: 73.0, Predicted: 70.31337278695048
# Actual: 70.0, Predicted: 69.47016599354198
# Actual: 63.0, Predicted: 66.94975179017621
# Actual: 66.0, Predicted: 63.01148427431403
# Actual: 57.0, Predicted: 56.88769722398189
# Actual: 58.0, Predicted: 59.567941333302784
# Actual: 63.0, Predicted: 65.44398894299809
# Actual: 57.0, Predicted: 58.63215119435155
# Actual: 62.0, Predicted: 60.026248231589435
# Actual: 66.0, Predicted: 64.43104022781596
# Actual: 65.0, Predicted: 65.48166405455584
# Actual: 52.0, Predicted: 56.85291138367015
# Actual: 68.0, Predicted: 67.42570311141695
# Actual: 65.0, Predicted: 65.61667847791077
# Actual: 57.0, Predicted: 57.412808185435594
# Actual: 74.0, Predicted: 74.90054087465839
# Actual: 58.0, Predicted: 60.539932206792145
# Actual: 60.0, Predicted: 65.62069378983519
# Actual: 52.0, Predicted: 53.245527973353916
# Actual: 73.0, Predicted: 69.81386646046775
# Actual: 69.0, Predicted: 68.08019328086527
# Actual: 67.0, Predicted: 65.60920202159244
# Actual: 67.0, Predicted: 67.66391590625706
# Actual: 62.0, Predicted: 61.42403337437632
# Actual: 66.0, Predicted: 64.83713004199075
# Actual: 66.0, Predicted: 65.46676091429345
# Actual: 68.0, Predicted: 68.83242762294998
# Actual: 56.0, Predicted: 52.98819548593846
# Actual: 54.0, Predicted: 54.74635723710054
# Actual: 55.0, Predicted: 54.16049804440583
# Actual: 66.0, Predicted: 68.0264309651104
# Actual: 70.0, Predicted: 71.81066173617839
# Actual: 69.0, Predicted: 66.8686835954128
# Actual: 68.0, Predicted: 65.39670731535364
# Actual: 72.0, Predicted: 71.74551282986745
# Actual: 60.0, Predicted: 61.09313669345974
# Actual: 62.0, Predicted: 61.626665564733685
# Actual: 77.0, Predicted: 76.13641596526413
# Actual: 52.0, Predicted: 51.29667753118213
# Actual: 68.0, Predicted: 66.80068171006893
# Actual: 65.0, Predicted: 64.48004701263793
# Actual: 64.0, Predicted: 64.93931837046937
# Actual: 62.0, Predicted: 61.75351133921872
# Actual: 79.0, Predicted: 78.81173323078488
# Actual: 70.0, Predicted: 72.23630883209927
# Actual: 59.0, Predicted: 57.94511933237635
# Actual: 63.0, Predicted: 64.7353934442034
# Actual: 58.0, Predicted: 55.49451576470713
# Actual: 75.0, Predicted: 72.73539655788947
# Actual: 68.0, Predicted: 66.2619146727851
# Actual: 68.0, Predicted: 68.22644911836721
# Actual: 67.0, Predicted: 65.07812783053905
# Actual: 69.0, Predicted: 67.39365164655669
# Actual: 63.0, Predicted: 68.24408792573163
# Actual: 58.0, Predicted: 58.50789283849862
# Actual: 70.0, Predicted: 67.54079417860933
# Actual: 71.0, Predicted: 69.55687418513851
# Actual: 66.0, Predicted: 67.19773491335316
# Actual: 63.0, Predicted: 64.18477540318146
# Actual: 83.0, Predicted: 83.53216006287784
# Actual: 54.0, Predicted: 55.650810111978515
# Actual: 72.0, Predicted: 69.64144984397703
# Actual: 64.0, Predicted: 61.90866536792221
# Actual: 79.0, Predicted: 78.5782614969744
# Actual: 67.0, Predicted: 65.45730072285117
# Actual: 71.0, Predicted: 70.620518957616
# Actual: 72.0, Predicted: 70.84613994912831
# Actual: 73.0, Predicted: 71.93370232010376
# Actual: 72.0, Predicted: 71.80480586950868
# Actual: 82.0, Predicted: 79.24336962740428
# Actual: 59.0, Predicted: 58.19773060391749
# Actual: 68.0, Predicted: 71.431580535535
# Actual: 69.0, Predicted: 71.93517551735765
# Actual: 60.0, Predicted: 61.529159200849065
# Actual: 72.0, Predicted: 71.16203933714114
# Actual: 66.0, Predicted: 68.32220765059506
# Actual: 74.0, Predicted: 76.19274156167442
# Actual: 68.0, Predicted: 66.91909530358387
# Actual: 54.0, Predicted: 57.87094482034739
# Actual: 66.0, Predicted: 64.67576238137785
# Actual: 63.0, Predicted: 64.63331860029577
# Actual: 63.0, Predicted: 65.4970348331235
# Actual: 75.0, Predicted: 72.95851162740055
# Actual: 58.0, Predicted: 61.305359488660955
# Actual: 55.0, Predicted: 52.91073796759699
# Actual: 57.0, Predicted: 57.76032699468563
# Actual: 63.0, Predicted: 61.553965898472654
# Actual: 69.0, Predicted: 66.90719269361533
# Actual: 59.0, Predicted: 59.95718539799519
# Actual: 56.0, Predicted: 58.517593398488685
# Actual: 77.0, Predicted: 77.09231504452362
# Actual: 65.0, Predicted: 63.56684964859561
# Actual: 66.0, Predicted: 65.010858211864
# Actual: 55.0, Predicted: 58.51365692209883
# Actual: 77.0, Predicted: 76.45419252028246
# Actual: 56.0, Predicted: 56.00499144121444
# Actual: 66.0, Predicted: 67.28344052325713
# Actual: 75.0, Predicted: 74.08096921479276
# Actual: 59.0, Predicted: 66.80083184116118
# Actual: 71.0, Predicted: 71.97463043104692
# Actual: 64.0, Predicted: 63.8775541411717
# Actual: 64.0, Predicted: 63.77819804800194
# Actual: 71.0, Predicted: 72.85556173215102
# Actual: 76.0, Predicted: 76.62874869535545
# Actual: 69.0, Predicted: 68.16223961808187
# Actual: 62.0, Predicted: 61.423551385511814
# Actual: 71.0, Predicted: 68.62512099856833
# Actual: 67.0, Predicted: 66.04858954098187
# Actual: 63.0, Predicted: 66.8003683809922
# Actual: 70.0, Predicted: 68.02722285306821
# Actual: 70.0, Predicted: 67.82790022160165
# Actual: 65.0, Predicted: 63.79038852072334
# Actual: 58.0, Predicted: 59.2354502797357
# Actual: 61.0, Predicted: 60.766175775530016
# Actual: 65.0, Predicted: 64.40744000144903
# Actual: 53.0, Predicted: 49.21643423107996
# Actual: 67.0, Predicted: 69.43628482559802
# Actual: 64.0, Predicted: 62.70103670722767
# Actual: 65.0, Predicted: 65.46507568927777
# Actual: 74.0, Predicted: 76.29189317478888
# Actual: 61.0, Predicted: 60.355503452700034
# Actual: 56.0, Predicted: 59.39002782176429
# Actual: 62.0, Predicted: 62.16229936231058
# Actual: 75.0, Predicted: 74.91922739471006
# Actual: 70.0, Predicted: 70.46517676229455
# Actual: 67.0, Predicted: 65.33545479489334
# Actual: 65.0, Predicted: 63.38568372726394
# Actual: 73.0, Predicted: 70.27955714399533
# Actual: 68.0, Predicted: 64.99593399022143
# Actual: 68.0, Predicted: 71.29665391600739
# Actual: 68.0, Predicted: 67.25160523925642
# Actual: 81.0, Predicted: 79.33052519589565
# Actual: 57.0, Predicted: 60.56812308294107
# Actual: 74.0, Predicted: 72.9773972428228
# Actual: 68.0, Predicted: 72.62306491505986
# Actual: 61.0, Predicted: 61.826952638439266
# Actual: 50.0, Predicted: 54.784768193593365
# Actual: 69.0, Predicted: 68.86284108941773
# Actual: 62.0, Predicted: 61.20813837279181
# Actual: 61.0, Predicted: 59.11645511890423
# Actual: 72.0, Predicted: 72.66354544166333
# Actual: 60.0, Predicted: 61.110622369928535
# Actual: 68.0, Predicted: 70.477635831782
# Actual: 76.0, Predicted: 75.01639898523675
# Actual: 68.0, Predicted: 66.40938069264114
# Actual: 70.0, Predicted: 70.90176190717379
# Actual: 51.0, Predicted: 53.58590031912075
# Actual: 72.0, Predicted: 75.56340962189418
# Actual: 66.0, Predicted: 65.0491331975717
# Actual: 47.0, Predicted: 51.64004234440513
# Actual: 71.0, Predicted: 71.52831090794476
# Actual: 62.0, Predicted: 62.47077503502105
# Actual: 72.0, Predicted: 70.75540419067248
# Actual: 62.0, Predicted: 61.60989670212773
# Actual: 63.0, Predicted: 58.25386602280639
# Actual: 78.0, Predicted: 77.59892460965939
# Actual: 56.0, Predicted: 54.92457343960727
# Actual: 80.0, Predicted: 77.28612792001131
# Actual: 64.0, Predicted: 64.59388772959696
# Actual: 74.0, Predicted: 72.80760506512237
# Actual: 74.0, Predicted: 75.60016618301113
# Actual: 60.0, Predicted: 60.711007146577856
# Actual: 66.0, Predicted: 64.91301695042354
# Actual: 63.0, Predicted: 64.75274625524138
# Actual: 71.0, Predicted: 72.02173865096849
# Actual: 70.0, Predicted: 67.78093695564972
# Actual: 71.0, Predicted: 67.94833066279428
# Actual: 75.0, Predicted: 76.29335752624786
# Actual: 59.0, Predicted: 58.85230426961773
# Actual: 69.0, Predicted: 69.22657044951409
# Actual: 59.0, Predicted: 59.231544146347304
# Actual: 61.0, Predicted: 59.62570309343836
# Actual: 70.0, Predicted: 70.29344112110691
# Actual: 81.0, Predicted: 81.67955511711551
# Actual: 79.0, Predicted: 78.28547670579992
# Actual: 62.0, Predicted: 58.38621055623656
# Actual: 61.0, Predicted: 58.59299583051221
# Actual: 58.0, Predicted: 56.96455207484267
# Actual: 74.0, Predicted: 71.47025808818285
# Actual: 72.0, Predicted: 71.2047183283849
# Actual: 64.0, Predicted: 66.52791537774826
# Actual: 61.0, Predicted: 61.50149614013233
# Actual: 68.0, Predicted: 68.18945822200726
# Actual: 62.0, Predicted: 59.9810370785481
# Actual: 64.0, Predicted: 63.8954795547195
# Actual: 74.0, Predicted: 73.71235299096324
# Actual: 70.0, Predicted: 70.25284763741568
# Actual: 63.0, Predicted: 61.65837848407415
# Actual: 63.0, Predicted: 64.1747514377829
# Actual: 60.0, Predicted: 65.04048927264026
# Actual: 78.0, Predicted: 82.40999737292519
# Actual: 63.0, Predicted: 67.20761316802417
# Actual: 69.0, Predicted: 66.53723824036628
# Actual: 70.0, Predicted: 71.72769639411302
# Actual: 65.0, Predicted: 64.2673394988682
# Actual: 67.0, Predicted: 63.98386568456749
# Actual: 76.0, Predicted: 73.65010780116938
# Actual: 79.0, Predicted: 78.47663222292482
# Actual: 69.0, Predicted: 69.4568191062531
# Actual: 61.0, Predicted: 64.85260079610394
# Actual: 75.0, Predicted: 72.45597933250578
# Actual: 59.0, Predicted: 58.03574853375008
# Actual: 67.0, Predicted: 66.40855919528921
# Actual: 64.0, Predicted: 62.69840542252766
# Actual: 73.0, Predicted: 72.44444228336066
# Actual: 59.0, Predicted: 56.17630225521668
# Actual: 65.0, Predicted: 62.44908247181448
# Actual: 67.0, Predicted: 64.68799446590448
# Actual: 65.0, Predicted: 63.56398062091458
# Actual: 71.0, Predicted: 69.32691366620641
# Actual: 64.0, Predicted: 61.62601399841306
# Actual: 72.0, Predicted: 69.7005284852594
# Actual: 62.0, Predicted: 64.56155440819765
# Actual: 67.0, Predicted: 68.74038539541876
# Actual: 72.0, Predicted: 73.09439293544332
# Actual: 65.0, Predicted: 63.870407291447464
# Actual: 63.0, Predicted: 66.36748747253594
# Actual: 74.0, Predicted: 75.37440596946603
# Actual: 74.0, Predicted: 74.12550196319215
# Actual: 68.0, Predicted: 69.54667393098116
# Actual: 62.0, Predicted: 62.99752280613369
# Actual: 64.0, Predicted: 67.76244654454226
# Actual: 70.0, Predicted: 68.94838726867145
# Actual: 62.0, Predicted: 57.61044451193639
# Actual: 81.0, Predicted: 77.88387749858167
# Actual: 67.0, Predicted: 66.9946469919108
# Actual: 67.0, Predicted: 63.99281796435322
# Actual: 68.0, Predicted: 67.42130333104787
# Actual: 59.0, Predicted: 61.01751076501263
# Actual: 85.0, Predicted: 86.06266306142516
# Actual: 63.0, Predicted: 62.26749175940671
# Actual: 70.0, Predicted: 70.40530662394092
# Actual: 62.0, Predicted: 63.84639471866157
# Actual: 61.0, Predicted: 62.65699154324173
# Actual: 54.0, Predicted: 55.2586286036872
# Actual: 67.0, Predicted: 65.71318662629206
# Actual: 57.0, Predicted: 58.2544700859646
# Actual: 63.0, Predicted: 61.86572756498836
# Actual: 68.0, Predicted: 71.04529347692014
# Actual: 71.0, Predicted: 69.64175562377656
# Actual: 76.0, Predicted: 74.02315267278904
# Actual: 65.0, Predicted: 63.848235614434515
# Actual: 67.0, Predicted: 66.29644439316212
# Actual: 66.0, Predicted: 63.36530818549353
# Actual: 63.0, Predicted: 61.56658221225365
# Actual: 63.0, Predicted: 63.246522698680835
# Actual: 69.0, Predicted: 69.41140778464452
# Actual: 68.0, Predicted: 70.32028111251863
# Actual: 65.0, Predicted: 62.048567806194825
# Actual: 72.0, Predicted: 70.88922329493779
# Actual: 52.0, Predicted: 54.27882941162177
# Actual: 76.0, Predicted: 72.15013954372074
# Actual: 67.0, Predicted: 63.8616150583413
# Actual: 60.0, Predicted: 61.337016667041325
# Actual: 70.0, Predicted: 69.82208205105503
# Actual: 63.0, Predicted: 61.698618909259054
# Actual: 81.0, Predicted: 81.13653349780486
# Actual: 57.0, Predicted: 57.48064808504999
# Actual: 57.0, Predicted: 57.8678553764876
# Actual: 70.0, Predicted: 69.27114285918212
# Actual: 72.0, Predicted: 71.04615098496019
# Actual: 67.0, Predicted: 63.07172459560972
# Actual: 63.0, Predicted: 60.878669721724904
# Actual: 61.0, Predicted: 59.98122573102442
# Actual: 77.0, Predicted: 78.12070526293638
# Actual: 59.0, Predicted: 57.08197157834472
# Actual: 61.0, Predicted: 65.82567348305335
# Actual: 63.0, Predicted: 61.95772086350452
# Actual: 57.0, Predicted: 58.587656481877545
# Actual: 80.0, Predicted: 76.80905243260165
# Actual: 73.0, Predicted: 69.8490958412323
# Actual: 66.0, Predicted: 63.502431951443555
# Actual: 65.0, Predicted: 61.61271401893826
# Actual: 71.0, Predicted: 68.86650363399055
# Actual: 71.0, Predicted: 70.67944606426137
# Actual: 71.0, Predicted: 68.62579275088594
# Actual: 71.0, Predicted: 71.73004066314297
# Actual: 72.0, Predicted: 71.61021992961105
# Actual: 70.0, Predicted: 68.66702015389765
# Actual: 75.0, Predicted: 74.78328209732128
# Actual: 72.0, Predicted: 71.7118030068864
# Actual: 73.0, Predicted: 72.19173008983562
# Actual: 52.0, Predicted: 54.059932246710915
# Actual: 68.0, Predicted: 64.838960570436
# Actual: 63.0, Predicted: 63.973863220268626
# Actual: 66.0, Predicted: 65.23138378639712
# Actual: 67.0, Predicted: 64.54802679872842
# Actual: 63.0, Predicted: 61.04024749111059
# Actual: 72.0, Predicted: 71.73986046520685
# Actual: 77.0, Predicted: 77.50598933831306
# Actual: 66.0, Predicted: 68.113908710378
# Actual: 62.0, Predicted: 64.26123866363251
# Actual: 73.0, Predicted: 74.2788654451258
# Actual: 55.0, Predicted: 55.87883330908832
# Actual: 71.0, Predicted: 76.23511643680621
# Actual: 73.0, Predicted: 72.67608670923524
# Actual: 67.0, Predicted: 65.45998438675004
# Actual: 58.0, Predicted: 54.86717236515953
# Actual: 72.0, Predicted: 69.99586554812603
# Actual: 75.0, Predicted: 76.57539600757492
# Actual: 65.0, Predicted: 65.44678799996005
# Actual: 65.0, Predicted: 64.60918417552608
# Actual: 61.0, Predicted: 62.83564720955252
# Actual: 65.0, Predicted: 64.58653167782772
# Actual: 73.0, Predicted: 72.01142774392305
# Actual: 52.0, Predicted: 52.53848965474556
# Actual: 73.0, Predicted: 73.52043062155332
# Actual: 67.0, Predicted: 65.69849246346965
# Actual: 69.0, Predicted: 69.38454039821406
# Actual: 52.0, Predicted: 54.12955044306551
# Actual: 61.0, Predicted: 59.90016865145377
# Actual: 65.0, Predicted: 62.70832373811703
# Actual: 53.0, Predicted: 54.69360595767725
# Actual: 75.0, Predicted: 73.215413843855
# Actual: 63.0, Predicted: 60.898932070836935
# Actual: 62.0, Predicted: 63.31366336594225
# Actual: 65.0, Predicted: 68.68352664457863
# Actual: 63.0, Predicted: 60.081638811073404
# Actual: 74.0, Predicted: 73.22886605983948
# Actual: 57.0, Predicted: 62.195271460872064
# Actual: 55.0, Predicted: 52.5959908446001
# Actual: 69.0, Predicted: 68.08603409469848
# Actual: 64.0, Predicted: 62.671480742065484
# Actual: 66.0, Predicted: 65.3293111392996
# Actual: 66.0, Predicted: 65.7421224082599
# Actual: 61.0, Predicted: 61.02155754534202
# Actual: 66.0, Predicted: 65.04363930045744
# Actual: 70.0, Predicted: 67.2684401452925
# Actual: 63.0, Predicted: 62.85181490781132
# Actual: 53.0, Predicted: 51.50693235098503
# Actual: 59.0, Predicted: 58.6143237605218
# Actual: 75.0, Predicted: 77.03199151446967
# Actual: 62.0, Predicted: 62.04983578624142
# Actual: 66.0, Predicted: 63.1178080656308
# Actual: 84.0, Predicted: 84.68756603895388
# Actual: 76.0, Predicted: 75.72941243573668
# Actual: 73.0, Predicted: 69.82489030862082
# ...
# Actual: 70.0, Predicted: 70.80258872273532
# Actual: 71.0, Predicted: 70.94184322475722
# Actual: 55.0, Predicted: 59.926592271148095
# Actual: 62.0, Predicted: 62.42627174567605
# Actual: 71.0, Predicted: 69.73319143683351
# Actual: 62.0, Predicted: 64.40375914323104
# Actual: 56.0, Predicted: 57.384463975253595
# Actual: 67.0, Predicted: 67.84123342071196
# Actual: 60.0, Predicted: 59.45930680092303
# Actual: 81.0, Predicted: 82.05272133016297
# Actual: 58.0, Predicted: 59.63974796948925
# Actual: 69.0, Predicted: 68.30791814026797
# Actual: 63.0, Predicted: 65.04255642209067
# Actual: 63.0, Predicted: 63.6808279685787
# Actual: 70.0, Predicted: 72.57647610621284
# Actual: 55.0, Predicted: 54.53055570621004
# Actual: 67.0, Predicted: 67.25628696184948
# Actual: 66.0, Predicted: 67.87218776142613
# Actual: 66.0, Predicted: 67.23529974718906
# Actual: 54.0, Predicted: 52.52303296356547
# Actual: 71.0, Predicted: 69.3114661031395
# Actual: 63.0, Predicted: 65.82132322808661
# Actual: 59.0, Predicted: 62.17630762055839
# Actual: 75.0, Predicted: 74.59950043349531
# Actual: 60.0, Predicted: 61.78934232619925
# Actual: 69.0, Predicted: 69.6491956963527
# Actual: 54.0, Predicted: 55.55368404156437
# Actual: 60.0, Predicted: 63.88232557544737
# Actual: 67.0, Predicted: 67.36264711400028
# Actual: 60.0, Predicted: 62.135594124733075
# Actual: 63.0, Predicted: 64.05641031965142
# Actual: 50.0, Predicted: 58.36299928753097
# Actual: 66.0, Predicted: 65.23072429378992
# Actual: 66.0, Predicted: 65.31016274084152
# Actual: 68.0, Predicted: 67.75214351936359
# Actual: 71.0, Predicted: 73.35086723285468
# Actual: 69.0, Predicted: 68.12976081195639
# Actual: 69.0, Predicted: 66.66461084186194
# Actual: 75.0, Predicted: 73.90629447725074
# Actual: 80.0, Predicted: 77.00000383959699
# Actual: 57.0, Predicted: 57.178747808663985
# Actual: 68.0, Predicted: 66.38335579194407
# Actual: 72.0, Predicted: 70.50899965146526
# Actual: 75.0, Predicted: 76.37365901526414
# Actual: 66.0, Predicted: 65.84577104354064
# Actual: 70.0, Predicted: 69.17680489500421
# Actual: 67.0, Predicted: 68.4778999544574
# Actual: 85.0, Predicted: 88.32805575635575
# Actual: 61.0, Predicted: 61.825920068581965
# Actual: 69.0, Predicted: 68.09833614476096
# Actual: 66.0, Predicted: 64.84347698732452
# Actual: 77.0, Predicted: 77.49102701605709
# Actual: 66.0, Predicted: 64.4871769193967
# Actual: 58.0, Predicted: 58.51103874272549
# Actual: 62.0, Predicted: 62.05887818106311
# Actual: 66.0, Predicted: 68.36388698630736
# Actual: 68.0, Predicted: 67.14580231387906
# Actual: 64.0, Predicted: 64.58328860177251
# Actual: 73.0, Predicted: 72.53962981382682
# Actual: 72.0, Predicted: 70.93696399783545
# Actual: 61.0, Predicted: 60.654616276882436
# Actual: 50.0, Predicted: 54.08885333688271
# Actual: 72.0, Predicted: 71.32570269584573
# Actual: 68.0, Predicted: 66.11809006584551
# Actual: 69.0, Predicted: 70.2621546980179
# Actual: 70.0, Predicted: 68.33270932551669
# Actual: 67.0, Predicted: 65.98875743699905
# Actual: 58.0, Predicted: 55.50603154649849
# Actual: 64.0, Predicted: 64.36458361905947
# Actual: 64.0, Predicted: 66.25028723247557
# Actual: 65.0, Predicted: 62.72519518121548
# Actual: 70.0, Predicted: 69.49014475292374
# Actual: 63.0, Predicted: 60.11937578614673
# Actual: 76.0, Predicted: 73.44618267679667
# Actual: 72.0, Predicted: 71.7046822133777
# Actual: 71.0, Predicted: 69.82567776627954
# Actual: 61.0, Predicted: 59.7873580513989
# Actual: 64.0, Predicted: 62.22179412953987
# Actual: 67.0, Predicted: 66.93918359374703
# Actual: 67.0, Predicted: 65.46517028580926
# Actual: 57.0, Predicted: 55.1347054728578
# Actual: 68.0, Predicted: 67.60964648137009
# Actual: 58.0, Predicted: 56.775657730965946
# Actual: 57.0, Predicted: 56.18948398787593
# Actual: 60.0, Predicted: 60.51459210777176
# Actual: 73.0, Predicted: 73.86810889848776
# Actual: 71.0, Predicted: 70.66504992061665
# Actual: 57.0, Predicted: 57.96665800138109
# Actual: 58.0, Predicted: 58.250411713512165
# Actual: 69.0, Predicted: 71.3706044615091
# Actual: 81.0, Predicted: 84.45197048262943
# Actual: 76.0, Predicted: 75.79528850389768
# Actual: 66.0, Predicted: 65.1529351109077
# Actual: 67.0, Predicted: 69.52142782164171
# Actual: 75.0, Predicted: 74.34735105717013
# Actual: 63.0, Predicted: 63.37943192551144
# Actual: 53.0, Predicted: 53.01862960878984
# Actual: 55.0, Predicted: 55.44453957555736
# Actual: 70.0, Predicted: 70.15840492470267
# Actual: 61.0, Predicted: 62.429843766700614
# Actual: 51.0, Predicted: 57.54530376271467
# Actual: 64.0, Predicted: 65.06506459695674
# Actual: 67.0, Predicted: 65.2413212370852
# Actual: 66.0, Predicted: 64.57280979868993
# Actual: 66.0, Predicted: 64.80236553459194
# Actual: 67.0, Predicted: 68.56193684023204
# Actual: 63.0, Predicted: 62.561527602992854
# Actual: 58.0, Predicted: 58.13159301829977
# Actual: 66.0, Predicted: 63.69288677316172
# Actual: 64.0, Predicted: 66.72254389489105
# Actual: 68.0, Predicted: 67.00291760791275
# Actual: 48.0, Predicted: 49.806596241506625
# Actual: 60.0, Predicted: 60.66910267143737
# Actual: 61.0, Predicted: 60.11787522073051
# Actual: 64.0, Predicted: 61.51034035183079
# Actual: 59.0, Predicted: 62.56772824633558
# Actual: 54.0, Predicted: 55.657277013567665
# Actual: 67.0, Predicted: 68.450195045363
# Actual: 60.0, Predicted: 59.37781500362594
# Actual: 59.0, Predicted: 60.12677402725565
# Actual: 70.0, Predicted: 70.04565650995987
# Actual: 69.0, Predicted: 67.69736566299213
# Actual: 72.0, Predicted: 73.87031167969953
# Actual: 66.0, Predicted: 66.58701692740189
# Actual: 68.0, Predicted: 63.7026183769717
# Actual: 70.0, Predicted: 69.75084071386017
# Actual: 58.0, Predicted: 56.427088083818816
# Actual: 51.0, Predicted: 54.38166706729544
# Actual: 67.0, Predicted: 62.79043024382638
# Actual: 79.0, Predicted: 78.51572599252253
# Actual: 54.0, Predicted: 58.3962823311542
# Actual: 64.0, Predicted: 62.246596418634766
# Actual: 69.0, Predicted: 67.9701790237602
# Actual: 66.0, Predicted: 65.72203344943888
# Actual: 70.0, Predicted: 70.18866019807643
# Actual: 61.0, Predicted: 64.44737416464358
# Actual: 70.0, Predicted: 66.75318501428504
# Actual: 65.0, Predicted: 65.20454249513035
# Actual: 67.0, Predicted: 65.05813983985303
# Actual: 69.0, Predicted: 71.81962185981374
# Actual: 53.0, Predicted: 55.351612250691275
# Actual: 71.0, Predicted: 70.9503006962294
# Actual: 64.0, Predicted: 63.89973214995332
# Actual: 81.0, Predicted: 79.84251133486949
# Actual: 74.0, Predicted: 75.10236558454841
# Actual: 71.0, Predicted: 72.81035417769662
# Actual: 64.0, Predicted: 64.32605795578442
# Actual: 61.0, Predicted: 57.98120116837994
# Actual: 52.0, Predicted: 57.99365318801843
# Actual: 63.0, Predicted: 63.45906164661507
# Actual: 69.0, Predicted: 69.28473598530105
# Actual: 65.0, Predicted: 67.1353552844269
# Actual: 70.0, Predicted: 67.79606771856623
# Actual: 60.0, Predicted: 59.00270589269451
# Actual: 63.0, Predicted: 62.07742477167007
# Actual: 61.0, Predicted: 60.17393053712475
# Actual: 60.0, Predicted: 57.366541441629636
# Actual: 69.0, Predicted: 67.7308290630266
# Actual: 67.0, Predicted: 66.17003815094691
# Actual: 66.0, Predicted: 64.01730979677909
# Actual: 65.0, Predicted: 66.10406119841339
# Actual: 66.0, Predicted: 65.58153820766866
# Actual: 70.0, Predicted: 69.51759718804026
# Actual: 73.0, Predicted: 73.38547540202336
# Actual: 67.0, Predicted: 69.02491310496669
# Actual: 69.0, Predicted: 70.04352320287366
# Actual: 64.0, Predicted: 63.136359630954345
# Actual: 74.0, Predicted: 71.60734306449181
# Actual: 52.0, Predicted: 60.79602138607757
# Actual: 69.0, Predicted: 68.38014308855394
# Actual: 60.0, Predicted: 61.50785032556203
# Actual: 74.0, Predicted: 76.02251162248798
# Actual: 68.0, Predicted: 69.45501745987391
# Actual: 75.0, Predicted: 71.900892651901
# Actual: 66.0, Predicted: 60.77760071369944
# Actual: 51.0, Predicted: 50.98249542386354
# Actual: 68.0, Predicted: 65.42788941168247
# Actual: 66.0, Predicted: 65.2341265872965
# Actual: 57.0, Predicted: 60.06743273387953
# Actual: 72.0, Predicted: 71.02538929201089
# Actual: 66.0, Predicted: 65.86115680421983
# Actual: 65.0, Predicted: 65.41683901007565
# Actual: 68.0, Predicted: 66.726050251319
# Actual: 68.0, Predicted: 67.29938531124833
# Actual: 62.0, Predicted: 61.4328445562881
# Actual: 75.0, Predicted: 74.9669949859149
# Actual: 69.0, Predicted: 67.2018148722057
# Actual: 60.0, Predicted: 60.796004680100765
# Actual: 86.0, Predicted: 90.10670146613938
# Actual: 63.0, Predicted: 61.85447498684117
# Actual: 66.0, Predicted: 64.59916849118136
# Actual: 64.0, Predicted: 64.33241966071951
# Actual: 63.0, Predicted: 61.73035298151949
# Actual: 63.0, Predicted: 62.10644157485574
# Actual: 55.0, Predicted: 55.66462817430333
# Actual: 61.0, Predicted: 62.39074977947885
# Actual: 73.0, Predicted: 72.40345198042377
# Actual: 65.0, Predicted: 64.7395968564967
# Actual: 70.0, Predicted: 68.98793489583349
# Actual: 66.0, Predicted: 65.19000805392963
# Actual: 61.0, Predicted: 59.73725843878516
# Actual: 64.0, Predicted: 63.828833787788184
# Actual: 71.0, Predicted: 71.19848766471168
# Actual: 72.0, Predicted: 69.64338644840447
# Actual: 69.0, Predicted: 65.00395993521886
# Actual: 66.0, Predicted: 65.15081325489541
# Actual: 84.0, Predicted: 81.38203333399727
# Actual: 63.0, Predicted: 61.22379277481211
# Actual: 73.0, Predicted: 71.91390339165851
# Actual: 63.0, Predicted: 61.137522850557644
# Actual: 63.0, Predicted: 63.42495460105465
# Actual: 66.0, Predicted: 66.64581898549604
# Actual: 66.0, Predicted: 63.396380592603236
# Actual: 74.0, Predicted: 76.42351791700473
# Actual: 69.0, Predicted: 70.55967371315575
# Actual: 66.0, Predicted: 65.59748238077034
# Actual: 74.0, Predicted: 73.81121166178357
# Actual: 64.0, Predicted: 62.231381129777546
# Actual: 64.0, Predicted: 64.5517741395782
# Actual: 58.0, Predicted: 55.22296228824278
# Actual: 66.0, Predicted: 63.5651334015089
# Actual: 66.0, Predicted: 63.72713088732749
# Actual: 51.0, Predicted: 49.5655763923446
# Actual: 72.0, Predicted: 70.31549710681911
# Actual: 61.0, Predicted: 63.503642976199814
# Actual: 61.0, Predicted: 66.67857858069617
# Actual: 64.0, Predicted: 65.64000617336238
# Actual: 61.0, Predicted: 63.41554350722423
# Actual: 69.0, Predicted: 69.2222328701663
# Actual: 56.0, Predicted: 56.69765334668277
# Actual: 67.0, Predicted: 68.28817808142054
# Actual: 66.0, Predicted: 63.03500720661465
# Actual: 66.0, Predicted: 64.52448747573948
# Actual: 68.0, Predicted: 67.3955437823675
# Actual: 73.0, Predicted: 73.0709043065781
# Actual: 58.0, Predicted: 57.830625754983956
# Actual: 53.0, Predicted: 54.55116620432702
# Actual: 75.0, Predicted: 76.29115803972864
# Actual: 89.0, Predicted: 92.48100021524023
# Actual: 66.0, Predicted: 64.35929723905215
# Actual: 62.0, Predicted: 61.169884356423225
# Actual: 70.0, Predicted: 67.6956597747565
# Actual: 63.0, Predicted: 62.05195378000647
# Actual: 63.0, Predicted: 67.87477252421047
# Actual: 51.0, Predicted: 48.02885586306833
# Actual: 66.0, Predicted: 68.39476737654505
# Actual: 50.0, Predicted: 53.484257876697725
# Actual: 71.0, Predicted: 71.7288392022265
# Actual: 72.0, Predicted: 71.59276172545947
# Actual: 61.0, Predicted: 60.74172849891286
# Actual: 62.0, Predicted: 63.047521779676785
# Actual: 73.0, Predicted: 72.44330471688112
# Actual: 75.0, Predicted: 73.99253247086511
# Actual: 59.0, Predicted: 60.517129615617606
# Actual: 61.0, Predicted: 66.71961303173595
# Actual: 71.0, Predicted: 69.81414744459175
# Actual: 65.0, Predicted: 67.42814202387368
# Actual: 70.0, Predicted: 69.94945732826393
# Actual: 74.0, Predicted: 70.02427513561965
# Actual: 67.0, Predicted: 66.22209118278822
# Actual: 61.0, Predicted: 60.84169390138629
# Actual: 63.0, Predicted: 64.44083366345296
# Actual: 71.0, Predicted: 72.9730519728107
# Actual: 71.0, Predicted: 70.29501850907815
# Actual: 71.0, Predicted: 70.9120709670259
# Actual: 83.0, Predicted: 81.7550972331603
# Actual: 62.0, Predicted: 62.38240786229268
# Actual: 54.0, Predicted: 56.817860594300654
# Actual: 71.0, Predicted: 70.86406860286367
# Actual: 69.0, Predicted: 65.7135672094125
# Actual: 65.0, Predicted: 64.02762343310052
# Actual: 79.0, Predicted: 79.76336208020821
# Actual: 66.0, Predicted: 64.4866826293909
# Actual: 70.0, Predicted: 70.09643924564607
# Actual: 68.0, Predicted: 67.86756118697015
# Actual: 57.0, Predicted: 58.44529285901221
# Actual: 58.0, Predicted: 60.57893921636625
# Actual: 61.0, Predicted: 60.22673184958778
# Actual: 58.0, Predicted: 55.376933319749696
# Actual: 75.0, Predicted: 76.95650337658479
# Actual: 72.0, Predicted: 71.69466277510821
# Actual: 66.0, Predicted: 65.80071428471192
# Actual: 64.0, Predicted: 65.44704155482192
# Actual: 61.0, Predicted: 59.50237786284413
# Actual: 75.0, Predicted: 73.27830777653354
# Actual: 60.0, Predicted: 59.89461904547248
# Actual: 59.0, Predicted: 62.90834354468994
# Actual: 64.0, Predicted: 65.45843790508476
# Actual: 71.0, Predicted: 71.88963944405292
# Actual: 60.0, Predicted: 62.31657572543956
# Actual: 62.0, Predicted: 60.398817635867786
# Actual: 67.0, Predicted: 67.98524416338721
# Actual: 71.0, Predicted: 68.18922011798955
# Actual: 59.0, Predicted: 56.92140773120532
# Actual: 70.0, Predicted: 67.12043394264906
# Actual: 60.0, Predicted: 59.61884660424994
# Actual: 67.0, Predicted: 65.90630581494919
# Actual: 72.0, Predicted: 69.98392086702131
# Actual: 74.0, Predicted: 73.35368027121345
# Actual: 79.0, Predicted: 74.22555976244622
# Actual: 84.0, Predicted: 88.21446310766441
# Actual: 65.0, Predicted: 63.3430722335583
# Actual: 53.0, Predicted: 58.33705487193484
# Actual: 54.0, Predicted: 55.2439708105711
# Actual: 48.0, Predicted: 48.388650431586576
# Actual: 64.0, Predicted: 64.99164522522231
# Actual: 54.0, Predicted: 57.39149327319694
# Actual: 60.0, Predicted: 59.33151227027058
# Actual: 76.0, Predicted: 77.82232932388294
# Actual: 64.0, Predicted: 62.967534800864556
# Actual: 67.0, Predicted: 64.91244569398074
# Actual: 69.0, Predicted: 69.37431975096915
# Actual: 68.0, Predicted: 68.067894962643
# Actual: 61.0, Predicted: 61.0392705131019
# Actual: 66.0, Predicted: 65.20807745088868
# Actual: 59.0, Predicted: 60.1122731708771
# Actual: 69.0, Predicted: 68.91507083329773
# Actual: 71.0, Predicted: 71.16806639259258
# Actual: 65.0, Predicted: 63.455356268747366
# Actual: 67.0, Predicted: 68.6674127128075
# Actual: 69.0, Predicted: 66.21975713435279
# Actual: 65.0, Predicted: 67.00034121453682
# Actual: 59.0, Predicted: 60.145818545386874
# Actual: 62.0, Predicted: 62.43061209734398
# Actual: 68.0, Predicted: 65.31264189992655
# Actual: 62.0, Predicted: 64.71948753004969
# Actual: 72.0, Predicted: 71.82933987832641
# Actual: 67.0, Predicted: 66.00174797613589
# Actual: 62.0, Predicted: 61.640056897570915
# Actual: 66.0, Predicted: 65.47121130334506
# Actual: 69.0, Predicted: 69.01184221526773
# Actual: 58.0, Predicted: 57.9364809312507
# Actual: 59.0, Predicted: 56.81684954498486
# Actual: 69.0, Predicted: 73.44466570107704
# Actual: 68.0, Predicted: 66.26371377788563
# Actual: 67.0, Predicted: 66.79793822151505
# Actual: 79.0, Predicted: 77.21452591129724
# Actual: 67.0, Predicted: 68.57383932383294
# Actual: 67.0, Predicted: 66.21558907257685
# Actual: 78.0, Predicted: 75.11347196960267
# Actual: 66.0, Predicted: 65.51251994097649
# Actual: 63.0, Predicted: 64.26972743600804
# Actual: 63.0, Predicted: 63.639581966809885
# Actual: 74.0, Predicted: 73.81390045169199
# Actual: 63.0, Predicted: 63.010073983981826
# Actual: 68.0, Predicted: 71.51935648135593
# Actual: 58.0, Predicted: 59.490341709338296
# Actual: 80.0, Predicted: 81.68130951211417
# Actual: 62.0, Predicted: 59.642294693980745
# Actual: 65.0, Predicted: 63.60089908203774
# Actual: 66.0, Predicted: 63.74944677247912
# Actual: 77.0, Predicted: 77.04132729923019
# Actual: 64.0, Predicted: 64.28822398213485
# Actual: 69.0, Predicted: 70.39772712987866
# Actual: 85.0, Predicted: 84.64880137015268
# Actual: 68.0, Predicted: 70.724516837023
# Actual: 72.0, Predicted: 71.33982070918158
# Actual: 68.0, Predicted: 65.9756645686936
# Actual: 61.0, Predicted: 58.13703798367496
# Actual: 69.0, Predicted: 69.13535899388636
# Actual: 72.0, Predicted: 71.11098668522293
# Actual: 69.0, Predicted: 69.02174668365083
# Actual: 73.0, Predicted: 73.78640476169998
# Actual: 66.0, Predicted: 67.80692410239992
# Actual: 64.0, Predicted: 65.47595009570124
# Actual: 63.0, Predicted: 61.10252258102469
# Actual: 56.0, Predicted: 56.36125849692489
# Actual: 50.0, Predicted: 50.924122443830775
# Actual: 75.0, Predicted: 72.9530372580096
# Actual: 66.0, Predicted: 65.52212787845062
# Actual: 68.0, Predicted: 66.31748895217747
# Actual: 67.0, Predicted: 66.57504737767334

# %%
# Create a color array, which can be based on any metric. Here we use the absolute error.
colors = np.abs(y_test - y_pred)

plt.scatter(y_test, y_pred, c=colors, cmap='viridis')
plt.colorbar(label='Error')  # Add a colorbar
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted')
plt.show()

# %%
# Assuming that 'y_test' are the actual values and 'y_pred' are the predicted values

# Calculate R-squared
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Calculate Root Mean Squared Error
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error: {rmse}')
print("Training set score: {:.2f}".format(ridge.score(X_train,y_train)))
print("Test set score: {:.2f}".format(ridge.score(X_test,y_test)))
# Out:
# R-squared: 0.9162180721906837
# Mean Squared Error: 3.9616052647733886
# Root Mean Squared Error: 1.990378171296447
# Training set score: 0.91
# Test set score: 0.92
